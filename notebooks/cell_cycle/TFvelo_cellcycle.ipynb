# %% [markdown]
# ## Run TFvelo

# %%
import pandas as pd
import anndata as ad
import scanpy as sc
import TFvelo as TFv

import numpy as np

import scvelo as scv
import matplotlib

# matplotlib.use('AGG')
import os, sys
import scipy

np.set_printoptions(suppress=True)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# from _calculation import get_gams
sys.path.append("../..")
from paths import DATA_DIR, FIG_DIR

# %% [markdown]
# ## Load the dataset and preprocessing according to input requirements of TFvelo

# %%
adata = sc.read("RegVelo_datasets/cell cycle/adata.h5ad")
adata.X = adata.layers["spliced"].copy()

del adata.layers["ambiguous"]
del adata.layers["matrix"]
del adata.layers["spanning"]

adata.obs.drop(
    [
        "Well_Plate",
        "plate",
        "MeanGreen530",
        "MeanRed585",
        "initial_size_unspliced",
        "initial_size_spliced",
        "initial_size",
    ],
    axis=1,
    inplace=True,
)
adata.var_names = adata.var["name"].values
adata.var.drop(adata.var.columns, axis=1, inplace=True)
adata.obs["pseudo_clusters"] = pd.cut(adata.obs["fucci_time"], bins=5, labels=False).astype(str).astype("category")
adata.obs["pseudo_clusters_equal_size"] = pd.qcut(adata.obs["fucci_time"], q=5, labels=False)
adata.obs["pseudo_clusters_equal_size_num"] = adata.obs["pseudo_clusters_equal_size"].astype(float)
adata.obs["cell_cycle_rad"] = adata.obs["fucci_time"] / adata.obs["fucci_time"].max() * 2 * np.pi
adata.uns["genes_all"] = np.array(adata.var_names)

if "spliced" in adata.layers:
    adata.layers["total"] = adata.layers["spliced"].todense() + adata.layers["unspliced"].todense()
elif "new" in adata.layers:
    adata.layers["total"] = np.array(adata.layers["total"].todense())
else:
    adata.layers["total"] = adata.X
adata.layers["total_raw"] = adata.layers["total"].copy()
n_cells, n_genes = adata.X.shape
sc.pp.filter_genes(adata, min_cells=int(n_cells / 50))
sc.pp.filter_cells(adata, min_genes=int(n_genes / 50))
TFv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000, log=True)  # include the following steps
adata.X = adata.layers["total"].copy()
# Out:
# Normalized count data: X, spliced, unspliced, total.
# Extracted 2000 highly variable genes.
# Logarithmized X.

# %% [markdown]
# ## Running TFvelo with default settings and save the output

# %%
gene_names = []
for tmp in adata.var_names:
    gene_names.append(tmp.upper())
adata.var_names = gene_names
adata.var_names_make_unique()
adata.obs_names_make_unique()

TFv.pp.moments(adata, n_pcs=30)

TFv.pp.get_TFs(adata, databases="ENCODE ChEA")
adata.uns["genes_pp"] = np.array(adata.var_names)
TFv.tl.recover_dynamics(
    adata,
    n_jobs=16,
    max_iter=20,
    var_names="all",
    WX_method="lsq_linear",
    WX_thres=20,
    n_top_genes=2000,
    fit_scaling=True,
    use_raw=0,
    init_weight_method="correlation",
    n_time_points=1000,
)
# Out:
# computing neighbors
#     finished (0:00:08) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'M_total', moments of total abundances (adata.layers)
# Get TFs according to ENCODE ChEA
# max_n_TF: 31
# mean_n_TF: 14.682
# gene num of 0 TF: 70
# total num of TFs: 47
# recovering dynamics (using 16/48 cores)
#   0%|          | 0/2000 [00:00<?, ?gene/s]
# Processing 0/125 TDRD5
# 0/125 TDRD5 FINISHED with n_TFs: 9
# Processing 1/125 KLHDC8A
# 1/125 KLHDC8A FINISHED with n_TFs: 14
# Processing 2/125 IL24
# 2/125 IL24 FINISHED with n_TFs: 13
# Processing 3/125 KCNF1
# 3/125 KCNF1 FINISHED with n_TFs: 13
# Processing 4/125 ACTG2
# 4/125 ACTG2 FINISHED with n_TFs: 5
# Processing 5/125 XIRP2
# 5/125 XIRP2 FINISHED with n_TFs: 7
# Processing 6/125 IVL
# 6/125 IVL FINISHED with n_TFs: 14
# Processing 7/125 SPRR2D
# 7/125 SPRR2D FINISHED with n_TFs: 9
# Processing 8/125 ARHGAP25
# 8/125 ARHGAP25 FINISHED with n_TFs: 15
# Processing 9/125 S100A9
# 9/125 S100A9 FINISHED with n_TFs: 9
# Processing 10/125 TGFA
# 10/125 TGFA FINISHED with n_TFs: 20
# Processing 11/125 GABRG1
# 11/125 GABRG1 FINISHED with n_TFs: 5
# Processing 12/125 ANTXR2
# 12/125 ANTXR2 FINISHED with n_TFs: 21
# Processing 13/125 PBXIP1
# 13/125 PBXIP1 FINISHED with n_TFs: 21
# Processing 14/125 CLDN1
# 14/125 CLDN1 FINISHED with n_TFs: 16
# Processing 15/125 COL6A3
# 15/125 COL6A3 FINISHED with n_TFs: 4
# Processing 16/125 TMEM169
# 16/125 TMEM169 FINISHED with n_TFs: 15
# Processing 17/125 IGFBP7
# 17/125 IGFBP7 FINISHED with n_TFs: 13
# Processing 18/125 CWC22
# 18/125 CWC22 FINISHED with n_TFs: 18
# Processing 19/125 TGFBR2
# 19/125 TGFBR2 FINISHED with n_TFs: 23
# Processing 20/125 ANKZF1
# 20/125 ANKZF1 FINISHED with n_TFs: 20
# Processing 21/125 DPPA2
# 21/125 DPPA2 FINISHED with n_TFs: 3
# SGO2 not recoverable due to n_TFs = 0
# WARNING: 22/125 SGO2 not recoverable due to insufficient samples.
# Processing 23/125 SERPINI1
# 23/125 SERPINI1 FINISHED with n_TFs: 21
# Processing 24/125 IFI16
# 24/125 IFI16 FINISHED with n_TFs: 18
# Processing 25/125 PTPN13
# 25/125 PTPN13 FINISHED with n_TFs: 18
# Processing 26/125 ADAMTS9
# 26/125 ADAMTS9 FINISHED with n_TFs: 11
# Processing 27/125 DCLK3
# 27/125 DCLK3 FINISHED with n_TFs: 6
# Processing 28/125 CXCL3
# 28/125 CXCL3 FINISHED with n_TFs: 11
# Processing 29/125 PLB1
# 29/125 PLB1 FINISHED with n_TFs: 5
# Processing 30/125 TGM4
# 30/125 TGM4 FINISHED with n_TFs: 5
# Processing 31/125 YEATS2
# 31/125 YEATS2 FINISHED with n_TFs: 16
# Processing 32/125 LIPH
# 32/125 LIPH FINISHED with n_TFs: 15
# Processing 33/125 RFC4
# 33/125 RFC4 FINISHED with n_TFs: 18
# Processing 34/125 ARHGEF3
# 34/125 ARHGEF3 FINISHED with n_TFs: 18
# Processing 35/125 SLBP
# 35/125 SLBP FINISHED with n_TFs: 24
# Processing 36/125 ABLIM2
# 36/125 ABLIM2 FINISHED with n_TFs: 18
# Processing 37/125 PLXNB1
# 37/125 PLXNB1 FINISHED with n_TFs: 23
# Processing 38/125 CAMKV
# 38/125 CAMKV FINISHED with n_TFs: 8
# Processing 39/125 MST1R
# 39/125 MST1R FINISHED with n_TFs: 17
# Processing 40/125 DUSP7
# 40/125 DUSP7 FINISHED with n_TFs: 22
# Processing 41/125 PPM1M
# 41/125 PPM1M FINISHED with n_TFs: 14
# Processing 42/125 PITX2
# 42/125 PITX2 FINISHED with n_TFs: 13
# Processing 43/125 HMGB2
# 43/125 HMGB2 FINISHED with n_TFs: 22
# GASK1B not recoverable due to n_TFs = 0
# WARNING: 44/125 GASK1B not recoverable due to insufficient samples.
# Processing 45/125 NPY1R
# 45/125 NPY1R FINISHED with n_TFs: 11
# Processing 46/125 ITGA2
# 46/125 ITGA2 FINISHED with n_TFs: 18
# Processing 47/125 MOCS2
# 47/125 MOCS2 FINISHED with n_TFs: 19
# Processing 48/125 EDIL3
# 48/125 EDIL3 FINISHED with n_TFs: 10
# Processing 49/125 TMEM161B
# 49/125 TMEM161B FINISHED with n_TFs: 17
# Processing 50/125 STARD4
# 50/125 STARD4 FINISHED with n_TFs: 22
# Processing 51/125 F2RL1
# 51/125 F2RL1 FINISHED with n_TFs: 16
# Processing 52/125 SPINK1
# 52/125 SPINK1 FINISHED with n_TFs: 1
# Processing 53/125 ESM1
# 53/125 ESM1 FINISHED with n_TFs: 10
# Processing 54/125 CMYA5
# 54/125 CMYA5 FINISHED with n_TFs: 7
# TENT2 not recoverable due to n_TFs = 0
# WARNING: 55/125 TENT2 not recoverable due to insufficient samples.
# Processing 56/125 EBF1
# 56/125 EBF1 FINISHED with n_TFs: 24
# Processing 57/125 TLR3
# 57/125 TLR3 FINISHED with n_TFs: 7
# Processing 58/125 CSF2
# 58/125 CSF2 FINISHED with n_TFs: 12
# Processing 59/125 GDF9
# 59/125 GDF9 FINISHED with n_TFs: 19
# Processing 60/125 TMEM200A
# 60/125 TMEM200A FINISHED with n_TFs: 6
# Processing 61/125 GPR85
# 61/125 GPR85 FINISHED with n_TFs: 13
# Processing 62/125 PTTG1
# 62/125 PTTG1 FINISHED with n_TFs: 18
# Processing 63/125 BMPER
# 63/125 BMPER FINISHED with n_TFs: 10
# Processing 64/125 SYTL3
# 64/125 SYTL3 FINISHED with n_TFs: 15
# Processing 65/125 CTSB
# 65/125 CTSB FINISHED with n_TFs: 23
# Processing 66/125 DLC1
# 66/125 DLC1 FINISHED with n_TFs: 10
# Processing 67/125 SUN3
# 67/125 SUN3 FINISHED with n_TFs: 8
# Processing 68/125 TNFRSF11B
# 68/125 TNFRSF11B FINISHED with n_TFs: 14
# Processing 69/125 SBSPON
# 69/125 SBSPON FINISHED with n_TFs: 3
# Processing 70/125 KCNV1
# 70/125 KCNV1 FINISHED with n_TFs: 7
# Processing 71/125 CSMD3
# 71/125 CSMD3 FINISHED with n_TFs: 14
# Processing 72/125 GEM
# 72/125 GEM FINISHED with n_TFs: 17
# Processing 73/125 PDP1
# 73/125 PDP1 FINISHED with n_TFs: 15
# Processing 74/125 SYK
# 74/125 SYK FINISHED with n_TFs: 14
# Processing 75/125 ABCA1
# 75/125 ABCA1 FINISHED with n_TFs: 14
# Processing 76/125 NFIL3
# 76/125 NFIL3 FINISHED with n_TFs: 23
# Processing 77/125 TMEM71
# 77/125 TMEM71 FINISHED with n_TFs: 9
# Processing 78/125 HGSNAT
# 78/125 HGSNAT FINISHED with n_TFs: 21
# Processing 79/125 SVEP1
# 79/125 SVEP1 FINISHED with n_TFs: 9
# Processing 80/125 ZHX1
# 80/125 ZHX1 FINISHED with n_TFs: 18
# Processing 81/125 CFAP47
# 81/125 CFAP47 FINISHED with n_TFs: 2
# Processing 82/125 DYNLT3
# 82/125 DYNLT3 FINISHED with n_TFs: 15
# SHOC1 not recoverable due to n_TFs = 0
# WARNING: 83/125 SHOC1 not recoverable due to insufficient samples.
# Processing 84/125 CLDN3
# 84/125 CLDN3 FINISHED with n_TFs: 11
# Processing 85/125 MELK
# 85/125 MELK FINISHED with n_TFs: 15
# Processing 86/125 FAT3
# 86/125 FAT3 FINISHED with n_TFs: 7
# Processing 87/125 PGM2L1
# 87/125 PGM2L1 FINISHED with n_TFs: 26
# Processing 88/125 OXGR1
# 88/125 OXGR1 FINISHED with n_TFs: 11
# Processing 89/125 PRPF18
# 89/125 PRPF18 FINISHED with n_TFs: 20
# Processing 90/125 VDAC2
# 90/125 VDAC2 FINISHED with n_TFs: 24
# Processing 91/125 TMEM52B
# 91/125 TMEM52B FINISHED with n_TFs: 4
# Processing 92/125 TSC1
# 92/125 TSC1 FINISHED with n_TFs: 20
# Processing 93/125 DDX21
# 93/125 DDX21 FINISHED with n_TFs: 26
# Processing 94/125 ZFYVE1
# 94/125 ZFYVE1 FINISHED with n_TFs: 24
# Processing 95/125 ANKRD2
# 95/125 ANKRD2 FINISHED with n_TFs: 10
# OTOGL not recoverable due to n_TFs = 0
# WARNING: 96/125 OTOGL not recoverable due to insufficient samples.
# Processing 97/125 NELL1
# 97/125 NELL1 FINISHED with n_TFs: 10
# Processing 98/125 HACD1
# 98/125 HACD1 FINISHED with n_TFs: 16
# Processing 99/125 HTRA1
# 99/125 HTRA1 FINISHED with n_TFs: 14
# Processing 100/125 TCP11L2
# 100/125 TCP11L2 FINISHED with n_TFs: 24
# Processing 101/125 ADAMTS15
# 101/125 ADAMTS15 FINISHED with n_TFs: 10
# Processing 102/125 GPT2
# 102/125 GPT2 FINISHED with n_TFs: 23
# Processing 103/125 FBN1
# 103/125 FBN1 FINISHED with n_TFs: 14
# Processing 104/125 RIC3
# 104/125 RIC3 FINISHED with n_TFs: 8
# Processing 105/125 WDR72
# 105/125 WDR72 FINISHED with n_TFs: 3
# Processing 106/125 CDYL2
# 106/125 CDYL2 FINISHED with n_TFs: 14
# Processing 107/125 PRTG
# 107/125 PRTG FINISHED with n_TFs: 18
# Processing 108/125 ZNF143
# 108/125 ZNF143 FINISHED with n_TFs: 18
# Processing 109/125 HSP90B1
# 109/125 HSP90B1 FINISHED with n_TFs: 27
# Processing 110/125 MMP10
# 110/125 MMP10 FINISHED with n_TFs: 7
# Processing 111/125 HTR3A
# 111/125 HTR3A FINISHED with n_TFs: 10
# Processing 112/125 SLFN5
# 112/125 SLFN5 FINISHED with n_TFs: 20
# Processing 113/125 FAM111A
# 113/125 FAM111A FINISHED with n_TFs: 18
# Processing 114/125 LDHD
# 114/125 LDHD FINISHED with n_TFs: 12
# Processing 115/125 NAV2
# 115/125 NAV2 FINISHED with n_TFs: 9
# Processing 116/125 PLK1
# 116/125 PLK1 FINISHED with n_TFs: 19
# Processing 117/125 NAB2
# 117/125 NAB2 FINISHED with n_TFs: 26
# Processing 118/125 SCG5
# 118/125 SCG5 FINISHED with n_TFs: 13
# Processing 119/125 MAP1A
# 119/125 MAP1A FINISHED with n_TFs: 9
# Processing 120/125 EVA1C
# 120/125 EVA1C FINISHED with n_TFs: 9
# Processing 121/125 NAT16
# 121/125 NAT16 FINISHED with n_TFs: 2
# Processing 122/125 SGSM1
# 122/125 SGSM1 FINISHED with n_TFs: 11
# Processing 123/125 TEF
# 123/125 TEF FINISHED with n_TFs: 17
# Processing 124/125 MEI1
# 124/125 MEI1 FINISHED with n_TFs: 7
# Processing 0/125 PARP8
# 0/125 PARP8 FINISHED with n_TFs: 22
# Processing 1/125 GFRA1
# 1/125 GFRA1 FINISHED with n_TFs: 10
# Processing 2/125 BAG3
# 2/125 BAG3 FINISHED with n_TFs: 19
# Processing 3/125 GRID2
# 3/125 GRID2 FINISHED with n_TFs: 8
# Processing 4/125 SETBP1
# 4/125 SETBP1 FINISHED with n_TFs: 19
# Processing 5/125 PDE3B
# 5/125 PDE3B FINISHED with n_TFs: 18
# Processing 6/125 SPOCK1
# 6/125 SPOCK1 FINISHED with n_TFs: 18
# Processing 7/125 GUCY1A2
# 7/125 GUCY1A2 FINISHED with n_TFs: 9
# Processing 8/125 JMY
# 8/125 JMY FINISHED with n_TFs: 24
# Processing 9/125 ZNF256
# 9/125 ZNF256 FINISHED with n_TFs: 9
# Processing 10/125 OLAH
# 10/125 OLAH FINISHED with n_TFs: 6
# Processing 11/125 ZFP36L2
# 11/125 ZFP36L2 FINISHED with n_TFs: 29
# Processing 12/125 IGSF10
# 12/125 IGSF10 FINISHED with n_TFs: 8
# Processing 13/125 GJA1
# 13/125 GJA1 FINISHED with n_TFs: 13
# Processing 14/125 SLC16A12
# 14/125 SLC16A12 FINISHED with n_TFs: 8
# Processing 15/125 MR1
# 15/125 MR1 FINISHED with n_TFs: 15
# Processing 16/125 PTPRR
# 16/125 PTPRR FINISHED with n_TFs: 9
# Processing 17/125 NR4A2
# 17/125 NR4A2 FINISHED with n_TFs: 21
# Processing 18/125 CD96
# 18/125 CD96 FINISHED with n_TFs: 11
# Processing 19/125 ADGRF4
# 19/125 ADGRF4 FINISHED with n_TFs: 8
# Processing 20/125 LURAP1L
# 20/125 LURAP1L FINISHED with n_TFs: 13
# Processing 21/125 ANKFN1
# 21/125 ANKFN1 FINISHED with n_TFs: 5
# Processing 22/125 SEMA3D
# 22/125 SEMA3D FINISHED with n_TFs: 5
# Processing 23/125 ANGPT1
# 23/125 ANGPT1 FINISHED with n_TFs: 14
# Processing 24/125 TNIK
# 24/125 TNIK FINISHED with n_TFs: 24
# Processing 25/125 C10ORF90
# 25/125 C10ORF90 FINISHED with n_TFs: 8
# Processing 26/125 PDE1C
# 26/125 PDE1C FINISHED with n_TFs: 6
# Processing 27/125 ADAMTS1
# 27/125 ADAMTS1 FINISHED with n_TFs: 16
# Processing 28/125 SLFN13
# 28/125 SLFN13 FINISHED with n_TFs: 11
# Processing 29/125 FGD5
# 29/125 FGD5 FINISHED with n_TFs: 7
# Processing 30/125 PIEZO2
# 30/125 PIEZO2 FINISHED with n_TFs: 9
# Processing 31/125 VOPP1
# 31/125 VOPP1 FINISHED with n_TFs: 26
# Processing 32/125 KLF10
# 32/125 KLF10 FINISHED with n_TFs: 25
# Processing 33/125 AGPAT5
# 33/125 AGPAT5 FINISHED with n_TFs: 25
# Processing 34/125 PDIA4
# 34/125 PDIA4 FINISHED with n_TFs: 21
# Processing 35/125 FZD7
# 35/125 FZD7 FINISHED with n_TFs: 20
# Processing 36/125 SPAG17
# 36/125 SPAG17 FINISHED with n_TFs: 16
# Processing 37/125 DEPTOR
# 37/125 DEPTOR FINISHED with n_TFs: 11
# Processing 38/125 PPARGC1B
# 38/125 PPARGC1B FINISHED with n_TFs: 20
# Processing 39/125 ELMO1
# 39/125 ELMO1 FINISHED with n_TFs: 16
# Processing 40/125 ADCY8
# 40/125 ADCY8 FINISHED with n_TFs: 10
# Processing 41/125 RAB39B
# 41/125 RAB39B FINISHED with n_TFs: 14
# Processing 42/125 CLIC2
# 42/125 CLIC2 FINISHED with n_TFs: 14
# Processing 43/125 MMP16
# 43/125 MMP16 FINISHED with n_TFs: 13
# Processing 44/125 MAP3K7CL
# 44/125 MAP3K7CL FINISHED with n_TFs: 8
# Processing 45/125 SORCS3
# 45/125 SORCS3 FINISHED with n_TFs: 11
# Processing 46/125 CD109
# 46/125 CD109 FINISHED with n_TFs: 20
# Processing 47/125 UBE2L6
# 47/125 UBE2L6 FINISHED with n_TFs: 17
# Processing 48/125 UNC5D
# 48/125 UNC5D FINISHED with n_TFs: 9
# Processing 49/125 ATAD2
# 49/125 ATAD2 FINISHED with n_TFs: 29
# Processing 50/125 FBXO32
# 50/125 FBXO32 FINISHED with n_TFs: 18
# ADGRG4 not recoverable due to n_TFs = 0
# WARNING: 51/125 ADGRG4 not recoverable due to insufficient samples.
# Processing 52/125 ZIC3
# 52/125 ZIC3 FINISHED with n_TFs: 10
# Processing 53/125 BUB1B
# 53/125 BUB1B FINISHED with n_TFs: 19
# Processing 54/125 NMNAT2
# 54/125 NMNAT2 FINISHED with n_TFs: 17
# Processing 55/125 TMEM171
# 55/125 TMEM171 FINISHED with n_TFs: 10
# Processing 56/125 NRG1
# 56/125 NRG1 FINISHED with n_TFs: 10
# Processing 57/125 ARMC12
# 57/125 ARMC12 FINISHED with n_TFs: 11
# Processing 58/125 CCNB2
# 58/125 CCNB2 FINISHED with n_TFs: 18
# PWWP3B not recoverable due to n_TFs = 0
# WARNING: 59/125 PWWP3B not recoverable due to insufficient samples.
# Processing 60/125 TSC22D3
# 60/125 TSC22D3 FINISHED with n_TFs: 13
# Processing 61/125 KCNJ15
# 61/125 KCNJ15 FINISHED with n_TFs: 10
# Processing 62/125 ETS2
# 62/125 ETS2 FINISHED with n_TFs: 21
# Processing 63/125 C9ORF43
# 63/125 C9ORF43 FINISHED with n_TFs: 18
# Processing 64/125 DGKI
# 64/125 DGKI FINISHED with n_TFs: 16
# Processing 65/125 FMNL2
# 65/125 FMNL2 FINISHED with n_TFs: 25
# GAREM2 not recoverable due to n_TFs = 0
# WARNING: 66/125 GAREM2 not recoverable due to insufficient samples.
# Processing 67/125 WDR66
# 67/125 WDR66 FINISHED with n_TFs: 10
# Processing 68/125 DUSP2
# 68/125 DUSP2 FINISHED with n_TFs: 23
# Processing 69/125 XDH
# 69/125 XDH FINISHED with n_TFs: 12
# Processing 70/125 ESYT3
# 70/125 ESYT3 FINISHED with n_TFs: 15
# TENT5B not recoverable due to n_TFs = 0
# WARNING: 71/125 TENT5B not recoverable due to insufficient samples.
# Processing 72/125 CLSTN2
# 72/125 CLSTN2 FINISHED with n_TFs: 10
# Processing 73/125 COLEC12
# 73/125 COLEC12 FINISHED with n_TFs: 15
# Processing 74/125 CDC25C
# 74/125 CDC25C FINISHED with n_TFs: 16
# Processing 75/125 HIST1H4H
# 75/125 HIST1H4H FINISHED with n_TFs: 21
# Processing 76/125 RIBC1
# 76/125 RIBC1 FINISHED with n_TFs: 15
# Processing 77/125 DNAH3
# 77/125 DNAH3 FINISHED with n_TFs: 12
# Processing 78/125 ZC3H18
# 78/125 ZC3H18 FINISHED with n_TFs: 19
# Processing 79/125 GDPD5
# 79/125 GDPD5 FINISHED with n_TFs: 20
# Processing 80/125 COPG2
# 80/125 COPG2 FINISHED with n_TFs: 14
# Processing 81/125 PINK1
# 81/125 PINK1 FINISHED with n_TFs: 22
# Processing 82/125 FAM160B2
# 82/125 FAM160B2 FINISHED with n_TFs: 13
# Processing 83/125 SLC5A11
# 83/125 SLC5A11 FINISHED with n_TFs: 16
# Processing 84/125 CCAR2
# 84/125 CCAR2 FINISHED with n_TFs: 17
# Processing 85/125 EPB41
# 85/125 EPB41 FINISHED with n_TFs: 21
# Processing 86/125 SON
# 86/125 SON FINISHED with n_TFs: 20
# Processing 87/125 STC1
# 87/125 STC1 FINISHED with n_TFs: 8
# Processing 88/125 CIART
# 88/125 CIART FINISHED with n_TFs: 8
# Processing 89/125 PTMS
# 89/125 PTMS FINISHED with n_TFs: 19
# Processing 90/125 PADI4
# 90/125 PADI4 FINISHED with n_TFs: 14
# Processing 91/125 C1R
# 91/125 C1R FINISHED with n_TFs: 12
# Processing 92/125 AMFR
# 92/125 AMFR FINISHED with n_TFs: 19
# Processing 93/125 ZNF230
# 93/125 ZNF230 FINISHED with n_TFs: 15
# Processing 94/125 NPR2
# 94/125 NPR2 FINISHED with n_TFs: 7
# Processing 95/125 PTGIR
# 95/125 PTGIR FINISHED with n_TFs: 14
# Processing 96/125 BSDC1
# 96/125 BSDC1 FINISHED with n_TFs: 24
# Processing 97/125 ZNF362
# 97/125 ZNF362 FINISHED with n_TFs: 17
# Processing 98/125 ABCG1
# 98/125 ABCG1 FINISHED with n_TFs: 14
# Processing 99/125 TFF2
# 99/125 TFF2 FINISHED with n_TFs: 2
# Processing 100/125 TMPRSS3
# 100/125 TMPRSS3 FINISHED with n_TFs: 12
# Processing 101/125 G6PD
# 101/125 G6PD FINISHED with n_TFs: 14
# Processing 102/125 IER2
# 102/125 IER2 FINISHED with n_TFs: 29
# Processing 103/125 SQSTM1
# 103/125 SQSTM1 FINISHED with n_TFs: 22
# Processing 104/125 RPL8
# 104/125 RPL8 FINISHED with n_TFs: 17
# Processing 105/125 RACGAP1
# 105/125 RACGAP1 FINISHED with n_TFs: 17
# Processing 106/125 CXCL16
# 106/125 CXCL16 FINISHED with n_TFs: 14
# Processing 107/125 CCNF
# 107/125 CCNF FINISHED with n_TFs: 18
# Processing 108/125 TAL1
# 108/125 TAL1 FINISHED with n_TFs: 12
# Processing 109/125 KLHL21
# 109/125 KLHL21 FINISHED with n_TFs: 27
# Processing 110/125 ZSWIM5
# 110/125 ZSWIM5 FINISHED with n_TFs: 14
# Processing 111/125 DRAXIN
# 111/125 DRAXIN FINISHED with n_TFs: 11
# Processing 112/125 LRRC38
# 112/125 LRRC38 FINISHED with n_TFs: 6
# Processing 113/125 DHRS3
# 113/125 DHRS3 FINISHED with n_TFs: 25
# Processing 114/125 LAPTM5
# 114/125 LAPTM5 FINISHED with n_TFs: 25
# Processing 115/125 SDC3
# 115/125 SDC3 FINISHED with n_TFs: 12
# Processing 116/125 ALPL
# 116/125 ALPL FINISHED with n_TFs: 11
# Processing 117/125 MXRA8
# 117/125 MXRA8 FINISHED with n_TFs: 18
# Processing 118/125 MEGF6
# 118/125 MEGF6 FINISHED with n_TFs: 11
# Processing 119/125 GBP2
# 119/125 GBP2 FINISHED with n_TFs: 18
# Processing 120/125 ZNF326
# 120/125 ZNF326 FINISHED with n_TFs: 21
# Processing 121/125 DDR2
# 121/125 DDR2 FINISHED with n_TFs: 18
# Processing 122/125 NCSTN
# 122/125 NCSTN FINISHED with n_TFs: 20
# Processing 123/125 OLFML2B
# 123/125 OLFML2B FINISHED with n_TFs: 18
# Processing 124/125 ATF3
# 124/125 ATF3 FINISHED with n_TFs: 24
# Processing 0/125 RAB11FIP4
# 0/125 RAB11FIP4 FINISHED with n_TFs: 14
# Processing 1/125 HACL1
# 1/125 HACL1 FINISHED with n_TFs: 19
# Processing 2/125 GALNT15
# 2/125 GALNT15 FINISHED with n_TFs: 5
# Processing 3/125 SLC6A6
# 3/125 SLC6A6 FINISHED with n_TFs: 22
# Processing 4/125 GFPT2
# 4/125 GFPT2 FINISHED with n_TFs: 13
# Processing 5/125 AOC2
# 5/125 AOC2 FINISHED with n_TFs: 6
# Processing 6/125 C1ORF159
# 6/125 C1ORF159 FINISHED with n_TFs: 23
# Processing 7/125 ANO1
# 7/125 ANO1 FINISHED with n_TFs: 10
# Processing 8/125 PPFIA1
# 8/125 PPFIA1 FINISHED with n_TFs: 17
# Processing 9/125 NINJ1
# 9/125 NINJ1 FINISHED with n_TFs: 21
# Processing 10/125 KRT34
# 10/125 KRT34 FINISHED with n_TFs: 3
# Processing 11/125 TNS4
# 11/125 TNS4 FINISHED with n_TFs: 15
# Processing 12/125 TOP2A
# 12/125 TOP2A FINISHED with n_TFs: 20
# Processing 13/125 PODNL1
# 13/125 PODNL1 FINISHED with n_TFs: 18
# Processing 14/125 DNAJB1
# 14/125 DNAJB1 FINISHED with n_TFs: 24
# Processing 15/125 NUP210
# 15/125 NUP210 FINISHED with n_TFs: 25
# Processing 16/125 IQCA1
# 16/125 IQCA1 FINISHED with n_TFs: 2
# Processing 17/125 PTPRE
# 17/125 PTPRE FINISHED with n_TFs: 17
# Processing 18/125 SERPINF1
# 18/125 SERPINF1 FINISHED with n_TFs: 16
# Processing 19/125 SLC52A1
# 19/125 SLC52A1 FINISHED with n_TFs: 2
# Processing 20/125 PCNA
# 20/125 PCNA FINISHED with n_TFs: 23
# Processing 21/125 RIN2
# 21/125 RIN2 FINISHED with n_TFs: 18
# Processing 22/125 SYT11
# 22/125 SYT11 FINISHED with n_TFs: 16
# Processing 23/125 ZSWIM3
# 23/125 ZSWIM3 FINISHED with n_TFs: 18
# Processing 24/125 AP3B1
# 24/125 AP3B1 FINISHED with n_TFs: 24
# PATJ not recoverable due to n_TFs = 0
# WARNING: 25/125 PATJ not recoverable due to insufficient samples.
# Processing 26/125 CASP9
# 26/125 CASP9 FINISHED with n_TFs: 24
# Processing 27/125 ATP8A2
# 27/125 ATP8A2 FINISHED with n_TFs: 14
# Processing 28/125 ALOX5AP
# 28/125 ALOX5AP FINISHED with n_TFs: 11
# Processing 29/125 CHRM3
# 29/125 CHRM3 FINISHED with n_TFs: 10
# Processing 30/125 CHI3L1
# 30/125 CHI3L1 FINISHED with n_TFs: 10
# Processing 31/125 LGR6
# 31/125 LGR6 FINISHED with n_TFs: 14
# Processing 32/125 DCLK1
# 32/125 DCLK1 FINISHED with n_TFs: 9
# Processing 33/125 BEX2
# 33/125 BEX2 FINISHED with n_TFs: 9
# Processing 34/125 BEX1
# 34/125 BEX1 FINISHED with n_TFs: 5
# Processing 35/125 CSNK1G2
# 35/125 CSNK1G2 FINISHED with n_TFs: 24
# Processing 36/125 MYO18B
# 36/125 MYO18B FINISHED with n_TFs: 13
# Processing 37/125 BTG1
# 37/125 BTG1 FINISHED with n_TFs: 27
# Processing 38/125 IMPA1
# 38/125 IMPA1 FINISHED with n_TFs: 20
# Processing 39/125 ARNTL
# 39/125 ARNTL FINISHED with n_TFs: 14
# Processing 40/125 AMPD3
# 40/125 AMPD3 FINISHED with n_TFs: 12
# Processing 41/125 MICAL2
# 41/125 MICAL2 FINISHED with n_TFs: 21
# Processing 42/125 UNC79
# 42/125 UNC79 FINISHED with n_TFs: 17
# Processing 43/125 TTC9
# 43/125 TTC9 FINISHED with n_TFs: 17
# Processing 44/125 CCNB1
# 44/125 CCNB1 FINISHED with n_TFs: 19
# Processing 45/125 CD180
# 45/125 CD180 FINISHED with n_TFs: 12
# Processing 46/125 IRAK2
# 46/125 IRAK2 FINISHED with n_TFs: 15
# Processing 47/125 BHLHE40
# 47/125 BHLHE40 FINISHED with n_TFs: 24
# Processing 48/125 PSRC1
# 48/125 PSRC1 FINISHED with n_TFs: 21
# Processing 49/125 SORT1
# 49/125 SORT1 FINISHED with n_TFs: 22
# Processing 50/125 TRIM45
# 50/125 TRIM45 FINISHED with n_TFs: 18
# Processing 51/125 SLC38A2
# 51/125 SLC38A2 FINISHED with n_TFs: 25
# Processing 52/125 GRHL1
# 52/125 GRHL1 FINISHED with n_TFs: 15
# Processing 53/125 MYCN
# 53/125 MYCN FINISHED with n_TFs: 18
# Processing 54/125 LPIN1
# 54/125 LPIN1 FINISHED with n_TFs: 25
# Processing 55/125 FST
# 55/125 FST FINISHED with n_TFs: 17
# Processing 56/125 SOX5
# 56/125 SOX5 FINISHED with n_TFs: 13
# Processing 57/125 KLRD1
# 57/125 KLRD1 FINISHED with n_TFs: 6
# Processing 58/125 MYBPC3
# 58/125 MYBPC3 FINISHED with n_TFs: 8
# Processing 59/125 DDB2
# 59/125 DDB2 FINISHED with n_TFs: 23
# Processing 60/125 CDCA8
# 60/125 CDCA8 FINISHED with n_TFs: 20
# Processing 61/125 AGO4
# 61/125 AGO4 FINISHED with n_TFs: 9
# Processing 62/125 FADS2
# 62/125 FADS2 FINISHED with n_TFs: 18
# Processing 63/125 TCN1
# 63/125 TCN1 FINISHED with n_TFs: 7
# Processing 64/125 COL4A2
# 64/125 COL4A2 FINISHED with n_TFs: 18
# Processing 65/125 UBAC2
# 65/125 UBAC2 FINISHED with n_TFs: 19
# Processing 66/125 ARHGAP32
# 66/125 ARHGAP32 FINISHED with n_TFs: 7
# Processing 67/125 ADAMTS8
# 67/125 ADAMTS8 FINISHED with n_TFs: 6
# Processing 68/125 SLC37A2
# 68/125 SLC37A2 FINISHED with n_TFs: 13
# CEMIP2 not recoverable due to n_TFs = 0
# WARNING: 69/125 CEMIP2 not recoverable due to insufficient samples.
# Processing 70/125 PSAT1
# 70/125 PSAT1 FINISHED with n_TFs: 24
# Processing 71/125 TBX3
# 71/125 TBX3 FINISHED with n_TFs: 18
# Processing 72/125 OASL
# 72/125 OASL FINISHED with n_TFs: 11
# Processing 73/125 HRK
# 73/125 HRK FINISHED with n_TFs: 11
# Processing 74/125 TRAFD1
# 74/125 TRAFD1 FINISHED with n_TFs: 23
# Processing 75/125 CD36
# 75/125 CD36 FINISHED with n_TFs: 3
# Processing 76/125 LMO2
# 76/125 LMO2 FINISHED with n_TFs: 24
# Processing 77/125 PHF21A
# 77/125 PHF21A FINISHED with n_TFs: 26
# Processing 78/125 EHF
# 78/125 EHF FINISHED with n_TFs: 14
# Processing 79/125 TROAP
# 79/125 TROAP FINISHED with n_TFs: 17
# Processing 80/125 ESPL1
# 80/125 ESPL1 FINISHED with n_TFs: 21
# Processing 81/125 ACVR1B
# 81/125 ACVR1B FINISHED with n_TFs: 15
# Processing 82/125 AHI1
# 82/125 AHI1 FINISHED with n_TFs: 27
# Processing 83/125 PKIB
# 83/125 PKIB FINISHED with n_TFs: 16
# Processing 84/125 DYSF
# 84/125 DYSF FINISHED with n_TFs: 20
# Processing 85/125 CPM
# 85/125 CPM FINISHED with n_TFs: 16
# Processing 86/125 MDM2
# 86/125 MDM2 FINISHED with n_TFs: 27
# PCNX2 not recoverable due to n_TFs = 0
# WARNING: 87/125 PCNX2 not recoverable due to insufficient samples.
# Processing 88/125 KCNK1
# 88/125 KCNK1 FINISHED with n_TFs: 21
# Processing 89/125 URB2
# 89/125 URB2 FINISHED with n_TFs: 19
# Processing 90/125 GLUL
# 90/125 GLUL FINISHED with n_TFs: 27
# Processing 91/125 RNASEL
# 91/125 RNASEL FINISHED with n_TFs: 17
# Processing 92/125 USP37
# 92/125 USP37 FINISHED with n_TFs: 21
# Processing 93/125 ITM2C
# 93/125 ITM2C FINISHED with n_TFs: 21
# Processing 94/125 SERPINE2
# 94/125 SERPINE2 FINISHED with n_TFs: 12
# Processing 95/125 ARMC9
# 95/125 ARMC9 FINISHED with n_TFs: 20
# Processing 96/125 EDAR
# 96/125 EDAR FINISHED with n_TFs: 12
# Processing 97/125 CKAP2
# 97/125 CKAP2 FINISHED with n_TFs: 17
# Processing 98/125 BORA
# 98/125 BORA FINISHED with n_TFs: 15
# Processing 99/125 SCEL
# 99/125 SCEL FINISHED with n_TFs: 10
# Processing 100/125 SPRY2
# 100/125 SPRY2 FINISHED with n_TFs: 26
# Processing 101/125 LCP1
# 101/125 LCP1 FINISHED with n_TFs: 18
# Processing 102/125 TNS3
# 102/125 TNS3 FINISHED with n_TFs: 20
# Processing 103/125 GPNMB
# 103/125 GPNMB FINISHED with n_TFs: 7
# Processing 104/125 RAPGEF5
# 104/125 RAPGEF5 FINISHED with n_TFs: 13
# Processing 105/125 AOAH
# 105/125 AOAH FINISHED with n_TFs: 6
# Processing 106/125 DGKB
# 106/125 DGKB FINISHED with n_TFs: 7
# Processing 107/125 HUS1
# 107/125 HUS1 FINISHED with n_TFs: 23
# Processing 108/125 TTC5
# 108/125 TTC5 FINISHED with n_TFs: 17
# Processing 109/125 NMT1
# 109/125 NMT1 FINISHED with n_TFs: 19
# Processing 110/125 MYCBPAP
# 110/125 MYCBPAP FINISHED with n_TFs: 17
# Processing 111/125 BRIP1
# 111/125 BRIP1 FINISHED with n_TFs: 22
# Processing 112/125 SCN2A
# 112/125 SCN2A FINISHED with n_TFs: 5
# Processing 113/125 GALNT5
# 113/125 GALNT5 FINISHED with n_TFs: 14
# Processing 114/125 VPS45
# 114/125 VPS45 FINISHED with n_TFs: 23
# IL36G not recoverable due to n_TFs = 0
# WARNING: 115/125 IL36G not recoverable due to insufficient samples.
# Processing 116/125 SMC2
# 116/125 SMC2 FINISHED with n_TFs: 20
# Processing 117/125 STXBP1
# 117/125 STXBP1 FINISHED with n_TFs: 16
# Processing 118/125 BAAT
# 118/125 BAAT FINISHED with n_TFs: 5
# Processing 119/125 TEX10
# 119/125 TEX10 FINISHED with n_TFs: 21
# Processing 120/125 TSTD2
# 120/125 TSTD2 FINISHED with n_TFs: 17
# Processing 121/125 GABBR2
# 121/125 GABBR2 FINISHED with n_TFs: 13
# Processing 122/125 CTSV
# 122/125 CTSV FINISHED with n_TFs: 8
# Processing 123/125 ENPP2
# 123/125 ENPP2 FINISHED with n_TFs: 7
# Processing 124/125 DSCC1
# 124/125 DSCC1 FINISHED with n_TFs: 16
# Processing 0/125 CDC45
# 0/125 CDC45 FINISHED with n_TFs: 20
# Processing 1/125 CDC6
# 1/125 CDC6 FINISHED with n_TFs: 20
# Processing 2/125 CRAT
# 2/125 CRAT FINISHED with n_TFs: 24
# Processing 3/125 SH2D3C
# 3/125 SH2D3C FINISHED with n_TFs: 20
# Processing 4/125 TBC1D2
# 4/125 TBC1D2 FINISHED with n_TFs: 22
# Processing 5/125 TMEM14A
# 5/125 TMEM14A FINISHED with n_TFs: 20
# Processing 6/125 DSP
# 6/125 DSP FINISHED with n_TFs: 18
# Processing 7/125 PCSK5
# 7/125 PCSK5 FINISHED with n_TFs: 14
# Processing 8/125 SCD
# 8/125 SCD FINISHED with n_TFs: 17
# Processing 9/125 ABLIM1
# 9/125 ABLIM1 FINISHED with n_TFs: 19
# Processing 10/125 NRP1
# 10/125 NRP1 FINISHED with n_TFs: 20
# Processing 11/125 MISP
# 11/125 MISP FINISHED with n_TFs: 13
# Processing 12/125 GADD45B
# 12/125 GADD45B FINISHED with n_TFs: 26
# Processing 13/125 RNF215
# 13/125 RNF215 FINISHED with n_TFs: 11
# Processing 14/125 CYTH4
# 14/125 CYTH4 FINISHED with n_TFs: 14
# Processing 15/125 LGALS1
# 15/125 LGALS1 FINISHED with n_TFs: 19
# Processing 16/125 PIK3IP1
# 16/125 PIK3IP1 FINISHED with n_TFs: 28
# Processing 17/125 MICALL1
# 17/125 MICALL1 FINISHED with n_TFs: 21
# Processing 18/125 TTC28
# 18/125 TTC28 FINISHED with n_TFs: 19
# Processing 19/125 KDELR3
# 19/125 KDELR3 FINISHED with n_TFs: 15
# Processing 20/125 XBP1
# 20/125 XBP1 FINISHED with n_TFs: 24
# Processing 21/125 RAB36
# 21/125 RAB36 FINISHED with n_TFs: 15
# Processing 22/125 LMF2
# 22/125 LMF2 FINISHED with n_TFs: 20
# Processing 23/125 TTLL1
# 23/125 TTLL1 FINISHED with n_TFs: 17
# Processing 24/125 HMOX1
# 24/125 HMOX1 FINISHED with n_TFs: 22
# Processing 25/125 MCM5
# 25/125 MCM5 FINISHED with n_TFs: 13
# Processing 26/125 PDGFB
# 26/125 PDGFB FINISHED with n_TFs: 16
# Processing 27/125 APOL1
# 27/125 APOL1 FINISHED with n_TFs: 17
# Processing 28/125 TNRC6B
# 28/125 TNRC6B FINISHED with n_TFs: 23
# Processing 29/125 IL2RB
# 29/125 IL2RB FINISHED with n_TFs: 9
# Processing 30/125 TRMU
# 30/125 TRMU FINISHED with n_TFs: 18
# Processing 31/125 KCNK10
# 31/125 KCNK10 FINISHED with n_TFs: 6
# Processing 32/125 ABHD4
# 32/125 ABHD4 FINISHED with n_TFs: 21
# Processing 33/125 RBM23
# 33/125 RBM23 FINISHED with n_TFs: 16
# Processing 34/125 PYGL
# 34/125 PYGL FINISHED with n_TFs: 21
# Processing 35/125 GNPNAT1
# 35/125 GNPNAT1 FINISHED with n_TFs: 21
# Processing 36/125 ISM2
# 36/125 ISM2 FINISHED with n_TFs: 13
# Processing 37/125 SUSD6
# 37/125 SUSD6 FINISHED with n_TFs: 15
# Processing 38/125 PSMC1
# 38/125 PSMC1 FINISHED with n_TFs: 16
# Processing 39/125 DHRS2
# 39/125 DHRS2 FINISHED with n_TFs: 14
# Processing 40/125 NFKBIA
# 40/125 NFKBIA FINISHED with n_TFs: 29
# Processing 41/125 MMP9
# 41/125 MMP9 FINISHED with n_TFs: 9
# Processing 42/125 MYBL2
# 42/125 MYBL2 FINISHED with n_TFs: 20
# Processing 43/125 NFATC2
# 43/125 NFATC2 FINISHED with n_TFs: 24
# Processing 44/125 BIRC7
# 44/125 BIRC7 FINISHED with n_TFs: 9
# Processing 45/125 CDC25B
# 45/125 CDC25B FINISHED with n_TFs: 19
# Processing 46/125 TRIB3
# 46/125 TRIB3 FINISHED with n_TFs: 21
# Processing 47/125 RASSF2
# 47/125 RASSF2 FINISHED with n_TFs: 17
# Processing 48/125 ANGPT4
# 48/125 ANGPT4 FINISHED with n_TFs: 6
# Processing 49/125 HCK
# 49/125 HCK FINISHED with n_TFs: 9
# Processing 50/125 POFUT1
# 50/125 POFUT1 FINISHED with n_TFs: 26
# Processing 51/125 MROH8
# 51/125 MROH8 FINISHED with n_TFs: 17
# Processing 52/125 JAG1
# 52/125 JAG1 FINISHED with n_TFs: 24
# Processing 53/125 E2F1
# 53/125 E2F1 FINISHED with n_TFs: 20
# Processing 54/125 RPRD1B
# 54/125 RPRD1B FINISHED with n_TFs: 20
# Processing 55/125 PPP1R16B
# 55/125 PPP1R16B FINISHED with n_TFs: 20
# Processing 56/125 FAM83D
# 56/125 FAM83D FINISHED with n_TFs: 21
# Processing 57/125 SYNDIG1
# 57/125 SYNDIG1 FINISHED with n_TFs: 6
# Processing 58/125 ST8SIA5
# 58/125 ST8SIA5 FINISHED with n_TFs: 10
# Processing 59/125 SMAD7
# 59/125 SMAD7 FINISHED with n_TFs: 28
# Processing 60/125 LAMA1
# 60/125 LAMA1 FINISHED with n_TFs: 11
# Processing 61/125 CSTF2
# 61/125 CSTF2 FINISHED with n_TFs: 16
# Processing 62/125 TBL1X
# 62/125 TBL1X FINISHED with n_TFs: 20
# Processing 63/125 SRPX
# 63/125 SRPX FINISHED with n_TFs: 6
# Processing 64/125 SMARCA1
# 64/125 SMARCA1 FINISHED with n_TFs: 14
# Processing 65/125 KCND1
# 65/125 KCND1 FINISHED with n_TFs: 7
# Processing 66/125 PHEX
# 66/125 PHEX FINISHED with n_TFs: 5
# Processing 67/125 TIMP1
# 67/125 TIMP1 FINISHED with n_TFs: 16
# Processing 68/125 KLHL4
# 68/125 KLHL4 FINISHED with n_TFs: 10
# Processing 69/125 MAGED2
# 69/125 MAGED2 FINISHED with n_TFs: 10
# Processing 70/125 SRPX2
# 70/125 SRPX2 FINISHED with n_TFs: 10
# Processing 71/125 ZDHHC15
# 71/125 ZDHHC15 FINISHED with n_TFs: 7
# Processing 72/125 DRP2
# 72/125 DRP2 FINISHED with n_TFs: 7
# RUBCNL not recoverable due to n_TFs = 0
# WARNING: 73/125 RUBCNL not recoverable due to insufficient samples.
# Processing 74/125 KLF5
# 74/125 KLF5 FINISHED with n_TFs: 24
# Processing 75/125 FGF9
# 75/125 FGF9 FINISHED with n_TFs: 19
# Processing 76/125 SGCG
# 76/125 SGCG FINISHED with n_TFs: 3
# Processing 77/125 FLT1
# 77/125 FLT1 FINISHED with n_TFs: 16
# Processing 78/125 TSC22D1
# 78/125 TSC22D1 FINISHED with n_TFs: 26
# Processing 79/125 MSLN
# 79/125 MSLN FINISHED with n_TFs: 9
# Processing 80/125 TSNAXIP1
# 80/125 TSNAXIP1 FINISHED with n_TFs: 19
# Processing 81/125 ZNF423
# 81/125 ZNF423 FINISHED with n_TFs: 6
# Processing 82/125 NDRG4
# 82/125 NDRG4 FINISHED with n_TFs: 10
# Processing 83/125 SLC7A6OS
# 83/125 SLC7A6OS FINISHED with n_TFs: 24
# Processing 84/125 USP10
# 84/125 USP10 FINISHED with n_TFs: 20
# CIAO3 not recoverable due to n_TFs = 0
# WARNING: 85/125 CIAO3 not recoverable due to insufficient samples.
# Processing 86/125 SLC7A5
# 86/125 SLC7A5 FINISHED with n_TFs: 24
# Processing 87/125 TOX3
# 87/125 TOX3 FINISHED with n_TFs: 11
# Processing 88/125 XYLT1
# 88/125 XYLT1 FINISHED with n_TFs: 14
# Processing 89/125 SYT17
# 89/125 SYT17 FINISHED with n_TFs: 15
# Processing 90/125 TMC5
# 90/125 TMC5 FINISHED with n_TFs: 11
# Processing 91/125 CSK
# 91/125 CSK FINISHED with n_TFs: 19
# Processing 92/125 CTSH
# 92/125 CTSH FINISHED with n_TFs: 15
# Processing 93/125 CEP152
# 93/125 CEP152 FINISHED with n_TFs: 16
# Processing 94/125 TGM5
# 94/125 TGM5 FINISHED with n_TFs: 9
# Processing 95/125 BMF
# 95/125 BMF FINISHED with n_TFs: 21
# Processing 96/125 CA2
# 96/125 CA2 FINISHED with n_TFs: 13
# Processing 97/125 EYA1
# 97/125 EYA1 FINISHED with n_TFs: 13
# Processing 98/125 POP1
# 98/125 POP1 FINISHED with n_TFs: 17
# Processing 99/125 PLAT
# 99/125 PLAT FINISHED with n_TFs: 12
# CCN4 not recoverable due to n_TFs = 0
# WARNING: 100/125 CCN4 not recoverable due to insufficient samples.
# Processing 101/125 STMN2
# 101/125 STMN2 FINISHED with n_TFs: 12
# Processing 102/125 TRPS1
# 102/125 TRPS1 FINISHED with n_TFs: 17
# Processing 103/125 SQLE
# 103/125 SQLE FINISHED with n_TFs: 20
# Processing 104/125 SH2D4A
# 104/125 SH2D4A FINISHED with n_TFs: 19
# Processing 105/125 MCM4
# 105/125 MCM4 FINISHED with n_TFs: 23
# Processing 106/125 KCNN4
# 106/125 KCNN4 FINISHED with n_TFs: 15
# Processing 107/125 KCNA7
# 107/125 KCNA7 FINISHED with n_TFs: 9
# Processing 108/125 IL4I1
# 108/125 IL4I1 FINISHED with n_TFs: 22
# Processing 109/125 TLE6
# 109/125 TLE6 FINISHED with n_TFs: 20
# Processing 110/125 NOVA2
# 110/125 NOVA2 FINISHED with n_TFs: 9
# Processing 111/125 ASF1B
# 111/125 ASF1B FINISHED with n_TFs: 22
# Processing 112/125 TNNT1
# 112/125 TNNT1 FINISHED with n_TFs: 7
# Processing 113/125 EPHX3
# 113/125 EPHX3 FINISHED with n_TFs: 9
# Processing 114/125 SYDE1
# 114/125 SYDE1 FINISHED with n_TFs: 9
# Processing 115/125 CCNE1
# 115/125 CCNE1 FINISHED with n_TFs: 16
# Processing 116/125 EBI3
# 116/125 EBI3 FINISHED with n_TFs: 16
# Processing 117/125 SLC1A5
# 117/125 SLC1A5 FINISHED with n_TFs: 19
# Processing 118/125 TJP3
# 118/125 TJP3 FINISHED with n_TFs: 15
# Processing 119/125 APLP1
# 119/125 APLP1 FINISHED with n_TFs: 11
# NOP53 not recoverable due to n_TFs = 0
# WARNING: 120/125 NOP53 not recoverable due to insufficient samples.
# Processing 121/125 PLA2G4C
# 121/125 PLA2G4C FINISHED with n_TFs: 16
# Processing 122/125 DBP
# 122/125 DBP FINISHED with n_TFs: 21
# Processing 123/125 RPL18A
# 123/125 RPL18A FINISHED with n_TFs: 17
# Processing 124/125 ISYNA1
# 124/125 ISYNA1 FINISHED with n_TFs: 17
# Processing 0/125 RHOB
# 0/125 RHOB FINISHED with n_TFs: 25
# Processing 1/125 ATP6V1C2
# 1/125 ATP6V1C2 FINISHED with n_TFs: 10
# Processing 2/125 MEIS1
# 2/125 MEIS1 FINISHED with n_TFs: 23
# Processing 3/125 SLC20A1
# 3/125 SLC20A1 FINISHED with n_TFs: 25
# Processing 4/125 NXPH2
# 4/125 NXPH2 FINISHED with n_TFs: 6
# Processing 5/125 THSD7B
# 5/125 THSD7B FINISHED with n_TFs: 10
# Processing 6/125 GULP1
# 6/125 GULP1 FINISHED with n_TFs: 20
# Processing 7/125 CCDC150
# 7/125 CCDC150 FINISHED with n_TFs: 18
# Processing 8/125 UNC80
# 8/125 UNC80 FINISHED with n_TFs: 10
# Processing 9/125 ABCA12
# 9/125 ABCA12 FINISHED with n_TFs: 16
# Processing 10/125 NYAP2
# 10/125 NYAP2 FINISHED with n_TFs: 2
# Processing 11/125 RHBDD1
# 11/125 RHBDD1 FINISHED with n_TFs: 23
# Processing 12/125 ACKR3
# 12/125 ACKR3 FINISHED with n_TFs: 8
# Processing 13/125 CNTN4
# 13/125 CNTN4 FINISHED with n_TFs: 11
# Processing 14/125 OSBPL10
# 14/125 OSBPL10 FINISHED with n_TFs: 17
# Processing 15/125 CSRNP1
# 15/125 CSRNP1 FINISHED with n_TFs: 19
# Processing 16/125 IL17RD
# 16/125 IL17RD FINISHED with n_TFs: 14
# Processing 17/125 NFKBIZ
# 17/125 NFKBIZ FINISHED with n_TFs: 26
# Processing 18/125 COL8A1
# 18/125 COL8A1 FINISHED with n_TFs: 10
# Processing 19/125 PHLDB2
# 19/125 PHLDB2 FINISHED with n_TFs: 8
# Processing 20/125 ABHD10
# 20/125 ABHD10 FINISHED with n_TFs: 19
# Processing 21/125 RABL3
# 21/125 RABL3 FINISHED with n_TFs: 19
# Processing 22/125 ADPRH
# 22/125 ADPRH FINISHED with n_TFs: 16
# Processing 23/125 NR1I2
# 23/125 NR1I2 FINISHED with n_TFs: 9
# Processing 24/125 TCTA
# 24/125 TCTA FINISHED with n_TFs: 19
# Processing 25/125 VWA5B2
# 25/125 VWA5B2 FINISHED with n_TFs: 12
# Processing 26/125 EPHA5
# 26/125 EPHA5 FINISHED with n_TFs: 13
# Processing 27/125 CAMK2D
# 27/125 CAMK2D FINISHED with n_TFs: 26
# Processing 28/125 ANK2
# 28/125 ANK2 FINISHED with n_TFs: 11
# Processing 29/125 CCNA2
# 29/125 CCNA2 FINISHED with n_TFs: 19
# Processing 30/125 PDGFC
# 30/125 PDGFC FINISHED with n_TFs: 14
# Processing 31/125 CDH18
# 31/125 CDH18 FINISHED with n_TFs: 8
# Processing 32/125 ADAMTS16
# 32/125 ADAMTS16 FINISHED with n_TFs: 5
# Processing 33/125 RPL37
# 33/125 RPL37 FINISHED with n_TFs: 19
# Processing 34/125 PLK2
# 34/125 PLK2 FINISHED with n_TFs: 20
# Processing 35/125 HAPLN1
# 35/125 HAPLN1 FINISHED with n_TFs: 10
# Processing 36/125 SSBP2
# 36/125 SSBP2 FINISHED with n_TFs: 27
# Processing 37/125 ANKRD31
# 37/125 ANKRD31 FINISHED with n_TFs: 14
# Processing 38/125 TSLP
# 38/125 TSLP FINISHED with n_TFs: 8
# Processing 39/125 GABRB2
# 39/125 GABRB2 FINISHED with n_TFs: 11
# Processing 40/125 TENM2
# 40/125 TENM2 FINISHED with n_TFs: 5
# Processing 41/125 PSD2
# 41/125 PSD2 FINISHED with n_TFs: 3
# Processing 42/125 GFRA3
# 42/125 GFRA3 FINISHED with n_TFs: 11
# Processing 43/125 PLA2G7
# 43/125 PLA2G7 FINISHED with n_TFs: 9
# Processing 44/125 TNFRSF21
# 44/125 TNFRSF21 FINISHED with n_TFs: 22
# Processing 45/125 PRSS35
# 45/125 PRSS35 FINISHED with n_TFs: 9
# Processing 46/125 PNRC1
# 46/125 PNRC1 FINISHED with n_TFs: 20
# Processing 47/125 CLVS2
# 47/125 CLVS2 FINISHED with n_TFs: 7
# Processing 48/125 SLC2A12
# 48/125 SLC2A12 FINISHED with n_TFs: 16
# Processing 49/125 CCZ1B
# 49/125 CCZ1B FINISHED with n_TFs: 12
# Processing 50/125 CREB5
# 50/125 CREB5 FINISHED with n_TFs: 11
# Processing 51/125 EGFR
# 51/125 EGFR FINISHED with n_TFs: 19
# Processing 52/125 ZNF92
# 52/125 ZNF92 FINISHED with n_TFs: 14
# Processing 53/125 TLK2
# 53/125 TLK2 FINISHED with n_TFs: 14
# Processing 54/125 SYTL5
# 54/125 SYTL5 FINISHED with n_TFs: 4
# Processing 55/125 KDM6A
# 55/125 KDM6A FINISHED with n_TFs: 18
# Processing 56/125 HDAC8
# 56/125 HDAC8 FINISHED with n_TFs: 17
# Processing 57/125 SLC16A2
# 57/125 SLC16A2 FINISHED with n_TFs: 8
# Processing 58/125 ZNF157
# 58/125 ZNF157 FINISHED with n_TFs: 2
# Processing 59/125 ZNF41
# 59/125 ZNF41 FINISHED with n_TFs: 13
# Processing 60/125 OGT
# 60/125 OGT FINISHED with n_TFs: 21
# GCNA not recoverable due to n_TFs = 0
# WARNING: 61/125 GCNA not recoverable due to insufficient samples.
# Processing 62/125 NXF3
# 62/125 NXF3 FINISHED with n_TFs: 3
# FRMPD3 not recoverable due to n_TFs = 0
# WARNING: 63/125 FRMPD3 not recoverable due to insufficient samples.
# Processing 64/125 GPC3
# 64/125 GPC3 FINISHED with n_TFs: 10
# Processing 65/125 CETN2
# 65/125 CETN2 FINISHED with n_TFs: 13
# Processing 66/125 CSGALNACT1
# 66/125 CSGALNACT1 FINISHED with n_TFs: 7
# Processing 67/125 SLC26A7
# 67/125 SLC26A7 FINISHED with n_TFs: 7
# Processing 68/125 ATP6V0D2
# 68/125 ATP6V0D2 FINISHED with n_TFs: 4
# Processing 69/125 SYBU
# 69/125 SYBU FINISHED with n_TFs: 5
# Processing 70/125 LRP12
# 70/125 LRP12 FINISHED with n_TFs: 20
# Processing 71/125 GSDMC
# 71/125 GSDMC FINISHED with n_TFs: 8
# Processing 72/125 FAM135B
# 72/125 FAM135B FINISHED with n_TFs: 2
# Processing 73/125 VLDLR
# 73/125 VLDLR FINISHED with n_TFs: 13
# Processing 74/125 PLIN2
# 74/125 PLIN2 FINISHED with n_TFs: 18
# Processing 75/125 NTRK2
# 75/125 NTRK2 FINISHED with n_TFs: 15
# Processing 76/125 GSN
# 76/125 GSN FINISHED with n_TFs: 17
# Processing 77/125 SURF6
# 77/125 SURF6 FINISHED with n_TFs: 19
# Processing 78/125 PTGES
# 78/125 PTGES FINISHED with n_TFs: 11
# Processing 79/125 LCN2
# 79/125 LCN2 FINISHED with n_TFs: 15
# Processing 80/125 HMCN2
# 80/125 HMCN2 FINISHED with n_TFs: 1
# Processing 81/125 CACNA1B
# 81/125 CACNA1B FINISHED with n_TFs: 10
# Processing 82/125 PARD3
# 82/125 PARD3 FINISHED with n_TFs: 15
# Processing 83/125 ZEB1
# 83/125 ZEB1 FINISHED with n_TFs: 17
# Processing 84/125 GLUD1
# 84/125 GLUD1 FINISHED with n_TFs: 24
# Processing 85/125 ANKRD1
# 85/125 ANKRD1 FINISHED with n_TFs: 15
# Processing 86/125 NPFFR1
# 86/125 NPFFR1 FINISHED with n_TFs: 9
# Processing 87/125 MKI67
# 87/125 MKI67 FINISHED with n_TFs: 20
# Processing 88/125 ADAM12
# 88/125 ADAM12 FINISHED with n_TFs: 14
# Processing 89/125 ADM
# 89/125 ADM FINISHED with n_TFs: 23
# Processing 90/125 GAS2
# 90/125 GAS2 FINISHED with n_TFs: 14
# Processing 91/125 SLC5A12
# 91/125 SLC5A12 FINISHED with n_TFs: 6
# Processing 92/125 LRRC4C
# 92/125 LRRC4C FINISHED with n_TFs: 9
# Processing 93/125 SYT8
# 93/125 SYT8 FINISHED with n_TFs: 12
# Processing 94/125 CCDC81
# 94/125 CCDC81 FINISHED with n_TFs: 5
# Processing 95/125 SESN3
# 95/125 SESN3 FINISHED with n_TFs: 18
# Processing 96/125 ST14
# 96/125 ST14 FINISHED with n_TFs: 18
# Processing 97/125 TMEM138
# 97/125 TMEM138 FINISHED with n_TFs: 18
# Processing 98/125 INCENP
# 98/125 INCENP FINISHED with n_TFs: 22
# Processing 99/125 SCN2B
# 99/125 SCN2B FINISHED with n_TFs: 9
# Processing 100/125 TAGLN
# 100/125 TAGLN FINISHED with n_TFs: 9
# Processing 101/125 DSN1
# 101/125 DSN1 FINISHED with n_TFs: 20
# Processing 102/125 MMP3
# 102/125 MMP3 FINISHED with n_TFs: 4
# Processing 103/125 ARID5B
# 103/125 ARID5B FINISHED with n_TFs: 27
# Processing 104/125 CDH8
# 104/125 CDH8 FINISHED with n_TFs: 8
# Processing 105/125 ADGRL3
# 105/125 ADGRL3 FINISHED with n_TFs: 1
# Processing 106/125 HNMT
# 106/125 HNMT FINISHED with n_TFs: 17
# Processing 107/125 PDCD4
# 107/125 PDCD4 FINISHED with n_TFs: 20
# Processing 108/125 ADRA2A
# 108/125 ADRA2A FINISHED with n_TFs: 15
# Processing 109/125 WDR17
# 109/125 WDR17 FINISHED with n_TFs: 12
# Processing 110/125 MTMR12
# 110/125 MTMR12 FINISHED with n_TFs: 23
# Processing 111/125 IL18
# 111/125 IL18 FINISHED with n_TFs: 10
# Processing 112/125 FREM2
# 112/125 FREM2 FINISHED with n_TFs: 17
# Processing 113/125 SEC24D
# 113/125 SEC24D FINISHED with n_TFs: 22
# Processing 114/125 SLC7A11
# 114/125 SLC7A11 FINISHED with n_TFs: 24
# Processing 115/125 DCP1B
# 115/125 DCP1B FINISHED with n_TFs: 18
# Processing 116/125 TMEM86A
# 116/125 TMEM86A FINISHED with n_TFs: 19
# Processing 117/125 ANK3
# 117/125 ANK3 FINISHED with n_TFs: 16
# Processing 118/125 AKAP6
# 118/125 AKAP6 FINISHED with n_TFs: 9
# Processing 119/125 ADAMTS12
# 119/125 ADAMTS12 FINISHED with n_TFs: 9
# Processing 120/125 VIPAS39
# 120/125 VIPAS39 FINISHED with n_TFs: 15
# Processing 121/125 TEX9
# 121/125 TEX9 FINISHED with n_TFs: 16
# Processing 122/125 DPYSL4
# 122/125 DPYSL4 FINISHED with n_TFs: 10
# Processing 123/125 ADAM8
# 123/125 ADAM8 FINISHED with n_TFs: 14
# Processing 124/125 TDO2
# 124/125 TDO2 FINISHED with n_TFs: 3
# Processing 0/125 DGKA
# 0/125 DGKA FINISHED with n_TFs: 20
# Processing 1/125 SPEN
# 1/125 SPEN FINISHED with n_TFs: 24
# Processing 2/125 MYLK
# 2/125 MYLK FINISHED with n_TFs: 13
# Processing 3/125 COL17A1
# 3/125 COL17A1 FINISHED with n_TFs: 5
# Processing 4/125 ZMYND12
# 4/125 ZMYND12 FINISHED with n_TFs: 20
# Processing 5/125 ASPM
# 5/125 ASPM FINISHED with n_TFs: 18
# Processing 6/125 KLF6
# 6/125 KLF6 FINISHED with n_TFs: 26
# Processing 7/125 NEO1
# 7/125 NEO1 FINISHED with n_TFs: 15
# Processing 8/125 TRAM1
# 8/125 TRAM1 FINISHED with n_TFs: 23
# Processing 9/125 PHKA1
# 9/125 PHKA1 FINISHED with n_TFs: 12
# Processing 10/125 NAV3
# 10/125 NAV3 FINISHED with n_TFs: 10
# Processing 11/125 ATP2B3
# 11/125 ATP2B3 FINISHED with n_TFs: 3
# Processing 12/125 RASSF1
# 12/125 RASSF1 FINISHED with n_TFs: 19
# Processing 13/125 ACSL4
# 13/125 ACSL4 FINISHED with n_TFs: 15
# Processing 14/125 INPP5A
# 14/125 INPP5A FINISHED with n_TFs: 19
# Processing 15/125 ATP11A
# 15/125 ATP11A FINISHED with n_TFs: 21
# Processing 16/125 PYGM
# 16/125 PYGM FINISHED with n_TFs: 11
# Processing 17/125 PAGE1
# 17/125 PAGE1 FINISHED with n_TFs: 5
# Processing 18/125 MAST4
# 18/125 MAST4 FINISHED with n_TFs: 12
# Processing 19/125 ADGRF5
# 19/125 ADGRF5 FINISHED with n_TFs: 2
# Processing 20/125 SDK2
# 20/125 SDK2 FINISHED with n_TFs: 13
# Processing 21/125 MAOB
# 21/125 MAOB FINISHED with n_TFs: 9
# Processing 22/125 TMEM260
# 22/125 TMEM260 FINISHED with n_TFs: 15
# Processing 23/125 CLTCL1
# 23/125 CLTCL1 FINISHED with n_TFs: 15
# Processing 24/125 FSTL3
# 24/125 FSTL3 FINISHED with n_TFs: 21
# Processing 25/125 RPS6KA2
# 25/125 RPS6KA2 FINISHED with n_TFs: 12
# Processing 26/125 ATP6AP1
# 26/125 ATP6AP1 FINISHED with n_TFs: 14
# Processing 27/125 TRIB2
# 27/125 TRIB2 FINISHED with n_TFs: 21
# Processing 28/125 RHOBTB1
# 28/125 RHOBTB1 FINISHED with n_TFs: 16
# Processing 29/125 HMMR
# 29/125 HMMR FINISHED with n_TFs: 20
# Processing 30/125 FBXW11
# 30/125 FBXW11 FINISHED with n_TFs: 24
# Processing 31/125 MCM2
# 31/125 MCM2 FINISHED with n_TFs: 21
# Processing 32/125 DHRS9
# 32/125 DHRS9 FINISHED with n_TFs: 11
# Processing 33/125 PTGS2
# 33/125 PTGS2 FINISHED with n_TFs: 18
# Processing 34/125 ST6GAL1
# 34/125 ST6GAL1 FINISHED with n_TFs: 18
# Processing 35/125 FRY
# 35/125 FRY FINISHED with n_TFs: 15
# Processing 36/125 CA12
# 36/125 CA12 FINISHED with n_TFs: 11
# Processing 37/125 NUAK1
# 37/125 NUAK1 FINISHED with n_TFs: 23
# Processing 38/125 SEMA3A
# 38/125 SEMA3A FINISHED with n_TFs: 12
# Processing 39/125 GTSE1
# 39/125 GTSE1 FINISHED with n_TFs: 14
# Processing 40/125 SEMA3C
# 40/125 SEMA3C FINISHED with n_TFs: 17
# Processing 41/125 RASAL2
# 41/125 RASAL2 FINISHED with n_TFs: 22
# Processing 42/125 FOSL2
# 42/125 FOSL2 FINISHED with n_TFs: 30
# Processing 43/125 FRYL
# 43/125 FRYL FINISHED with n_TFs: 20
# Processing 44/125 ACTB
# 44/125 ACTB FINISHED with n_TFs: 25
# Processing 45/125 MOCOS
# 45/125 MOCOS FINISHED with n_TFs: 18
# Processing 46/125 PLD1
# 46/125 PLD1 FINISHED with n_TFs: 27
# Processing 47/125 KIFAP3
# 47/125 KIFAP3 FINISHED with n_TFs: 22
# Processing 48/125 MCM6
# 48/125 MCM6 FINISHED with n_TFs: 21
# Processing 49/125 UNG
# 49/125 UNG FINISHED with n_TFs: 18
# Processing 50/125 PLXNA2
# 50/125 PLXNA2 FINISHED with n_TFs: 18
# Processing 51/125 GPATCH1
# 51/125 GPATCH1 FINISHED with n_TFs: 18
# Processing 52/125 GPC4
# 52/125 GPC4 FINISHED with n_TFs: 7
# Processing 53/125 CTTNBP2
# 53/125 CTTNBP2 FINISHED with n_TFs: 9
# Processing 54/125 ACTN2
# 54/125 ACTN2 FINISHED with n_TFs: 14
# Processing 55/125 MAP2
# 55/125 MAP2 FINISHED with n_TFs: 12
# Processing 56/125 AMPH
# 56/125 AMPH FINISHED with n_TFs: 11
# Processing 57/125 LAMP3
# 57/125 LAMP3 FINISHED with n_TFs: 13
# Processing 58/125 FAP
# 58/125 FAP FINISHED with n_TFs: 8
# Processing 59/125 NEBL
# 59/125 NEBL FINISHED with n_TFs: 15
# Processing 60/125 EDN1
# 60/125 EDN1 FINISHED with n_TFs: 18
# Processing 61/125 ADCYAP1R1
# 61/125 ADCYAP1R1 FINISHED with n_TFs: 7
# Processing 62/125 BRINP1
# 62/125 BRINP1 FINISHED with n_TFs: 6
# Processing 63/125 OSBPL6
# 63/125 OSBPL6 FINISHED with n_TFs: 22
# Processing 64/125 FDFT1
# 64/125 FDFT1 FINISHED with n_TFs: 18
# Processing 65/125 KIF22
# 65/125 KIF22 FINISHED with n_TFs: 20
# Processing 66/125 MOXD1
# 66/125 MOXD1 FINISHED with n_TFs: 17
# Processing 67/125 CRYBG3
# 67/125 CRYBG3 FINISHED with n_TFs: 2
# Processing 68/125 RFX3
# 68/125 RFX3 FINISHED with n_TFs: 25
# Processing 69/125 SLC4A4
# 69/125 SLC4A4 FINISHED with n_TFs: 12
# Processing 70/125 SESN1
# 70/125 SESN1 FINISHED with n_TFs: 26
# Processing 71/125 NDC80
# 71/125 NDC80 FINISHED with n_TFs: 18
# Processing 72/125 COL4A4
# 72/125 COL4A4 FINISHED with n_TFs: 11
# Processing 73/125 IMPG2
# 73/125 IMPG2 FINISHED with n_TFs: 6
# Processing 74/125 PTPRC
# 74/125 PTPRC FINISHED with n_TFs: 14
# Processing 75/125 CDC14B
# 75/125 CDC14B FINISHED with n_TFs: 21
# Processing 76/125 MPP4
# 76/125 MPP4 FINISHED with n_TFs: 13
# DOP1A not recoverable due to n_TFs = 0
# WARNING: 77/125 DOP1A not recoverable due to insufficient samples.
# TUT7 not recoverable due to n_TFs = 0
# WARNING: 78/125 TUT7 not recoverable due to insufficient samples.
# Processing 79/125 DIS3
# 79/125 DIS3 FINISHED with n_TFs: 19
# Processing 80/125 ZNF416
# 80/125 ZNF416 FINISHED with n_TFs: 13
# Processing 81/125 COL16A1
# 81/125 COL16A1 FINISHED with n_TFs: 23
# Processing 82/125 EFR3B
# 82/125 EFR3B FINISHED with n_TFs: 19
# Processing 83/125 KIF3C
# 83/125 KIF3C FINISHED with n_TFs: 15
# Processing 84/125 CD82
# 84/125 CD82 FINISHED with n_TFs: 20
# Processing 85/125 MECOM
# 85/125 MECOM FINISHED with n_TFs: 15
# Processing 86/125 OVGP1
# 86/125 OVGP1 FINISHED with n_TFs: 7
# Processing 87/125 AKR1B1
# 87/125 AKR1B1 FINISHED with n_TFs: 17
# Processing 88/125 TTC39A
# 88/125 TTC39A FINISHED with n_TFs: 12
# Processing 89/125 ORC1
# 89/125 ORC1 FINISHED with n_TFs: 17
# Processing 90/125 LAT2
# 90/125 LAT2 FINISHED with n_TFs: 15
# Processing 91/125 PPP1R15A
# 91/125 PPP1R15A FINISHED with n_TFs: 19
# Processing 92/125 FTL
# 92/125 FTL FINISHED with n_TFs: 20
# Processing 93/125 MMP2
# 93/125 MMP2 FINISHED with n_TFs: 12
# Processing 94/125 AURKA
# 94/125 AURKA FINISHED with n_TFs: 22
# Processing 95/125 ASAP3
# 95/125 ASAP3 FINISHED with n_TFs: 16
# Processing 96/125 EDEM2
# 96/125 EDEM2 FINISHED with n_TFs: 20
# Processing 97/125 TPX2
# 97/125 TPX2 FINISHED with n_TFs: 19
# Processing 98/125 ARHGAP28
# 98/125 ARHGAP28 FINISHED with n_TFs: 7
# Processing 99/125 KIF16B
# 99/125 KIF16B FINISHED with n_TFs: 20
# Processing 100/125 CHGB
# 100/125 CHGB FINISHED with n_TFs: 16
# Processing 101/125 TBX5
# 101/125 TBX5 FINISHED with n_TFs: 11
# Processing 102/125 NOS1
# 102/125 NOS1 FINISHED with n_TFs: 7
# Processing 103/125 HEPH
# 103/125 HEPH FINISHED with n_TFs: 18
# Processing 104/125 BIRC5
# 104/125 BIRC5 FINISHED with n_TFs: 20
# Processing 105/125 OTUB2
# 105/125 OTUB2 FINISHED with n_TFs: 16
# Processing 106/125 RCOR1
# 106/125 RCOR1 FINISHED with n_TFs: 26
# Processing 107/125 ICAM1
# 107/125 ICAM1 FINISHED with n_TFs: 21
# Processing 108/125 P3H2
# 108/125 P3H2 FINISHED with n_TFs: 12
# Processing 109/125 THPO
# 109/125 THPO FINISHED with n_TFs: 12
# Processing 110/125 AARS
# 110/125 AARS FINISHED with n_TFs: 21
# Processing 111/125 KIF4A
# 111/125 KIF4A FINISHED with n_TFs: 12
# Processing 112/125 NRCAM
# 112/125 NRCAM FINISHED with n_TFs: 13
# Processing 113/125 LAMB1
# 113/125 LAMB1 FINISHED with n_TFs: 14
# Processing 114/125 SLC26A4
# 114/125 SLC26A4 FINISHED with n_TFs: 18
# Processing 115/125 RAPGEF4
# 115/125 RAPGEF4 FINISHED with n_TFs: 13
# Processing 116/125 SEL1L3
# 116/125 SEL1L3 FINISHED with n_TFs: 18
# Processing 117/125 ZFHX4
# 117/125 ZFHX4 FINISHED with n_TFs: 13
# Processing 118/125 CD200
# 118/125 CD200 FINISHED with n_TFs: 13
# Processing 119/125 CCDC80
# 119/125 CCDC80 FINISHED with n_TFs: 13
# Processing 120/125 WDR76
# 120/125 WDR76 FINISHED with n_TFs: 18
# Processing 121/125 PHGDH
# 121/125 PHGDH FINISHED with n_TFs: 17
# Processing 122/125 CLSPN
# 122/125 CLSPN FINISHED with n_TFs: 20
# Processing 123/125 DPYSL2
# 123/125 DPYSL2 FINISHED with n_TFs: 15
# Processing 124/125 TGFB2
# 124/125 TGFB2 FINISHED with n_TFs: 21
# Processing 0/125 SH2D1B
# 0/125 SH2D1B FINISHED with n_TFs: 10
# Processing 1/125 ARC
# 1/125 ARC FINISHED with n_TFs: 16
# Processing 2/125 CCDC69
# 2/125 CCDC69 FINISHED with n_TFs: 17
# Processing 3/125 RYR2
# 3/125 RYR2 FINISHED with n_TFs: 13
# Processing 4/125 ABCA4
# 4/125 ABCA4 FINISHED with n_TFs: 10
# Processing 5/125 SMOC1
# 5/125 SMOC1 FINISHED with n_TFs: 14
# Processing 6/125 PLXNB3
# 6/125 PLXNB3 FINISHED with n_TFs: 16
# Processing 7/125 COLGALT2
# 7/125 COLGALT2 FINISHED with n_TFs: 10
# Processing 8/125 GRIN3A
# ...
# Processing Processing 0/125 HCLS1
# 0/125 HCLS1 FINISHED with n_TFs: 12
# Processing 1/125 GAS1
# 1/125 GAS1 FINISHED with n_TFs: 13
# Processing 2/125 HIST1H2AC
# 2/125 HIST1H2AC FINISHED with n_TFs: 19
# Processing 3/125 HIST1H2BC
# 3/125 HIST1H2BC FINISHED with n_TFs: 18
# Processing 4/125 MB21D2
# 4/125 MB21D2 FINISHED with n_TFs: 11
# Processing 5/125 SHISA2
# 5/125 SHISA2 FINISHED with n_TFs: 7
# Processing 6/125 ARSJ
# 6/125 ARSJ FINISHED with n_TFs: 13
# Processing 7/125 ZNF792
# 7/125 ZNF792 FINISHED with n_TFs: 15
# Processing 8/125 ZNF572
# 8/125 ZNF572 FINISHED with n_TFs: 12
# Processing 9/125 GPR137C
# 9/125 GPR137C FINISHED with n_TFs: 16
# Processing 10/125 BBS12
# 10/125 BBS12 FINISHED with n_TFs: 14
# Processing 11/125 F2R
# 11/125 F2R FINISHED with n_TFs: 18
# Processing 12/125 TMEM132C
# 12/125 TMEM132C FINISHED with n_TFs: 6
# Processing 13/125 HEPHL1
# 13/125 HEPHL1 FINISHED with n_TFs: 8
# Processing 14/125 SAGE1
# 14/125 SAGE1 FINISHED with n_TFs: 10
# Processing 15/125 TMEM45A
# 15/125 TMEM45A FINISHED with n_TFs: 13
# Processing 16/125 TNFSF15
# 16/125 TNFSF15 FINISHED with n_TFs: 13
# Processing 17/125 ZBTB20
# 17/125 ZBTB20 FINISHED with n_TFs: 19
# Processing 18/125 AMIGO1
# 18/125 AMIGO1 FINISHED with n_TFs: 13
# Processing 19/125 SLC2A4
# 19/125 SLC2A4 FINISHED with n_TFs: 22
# Processing 20/125 CCDC149
# 20/125 CCDC149 FINISHED with n_TFs: 9
# Processing 21/125 RTKN2
# 21/125 RTKN2 FINISHED with n_TFs: 13
# Processing 22/125 USH1G
# 22/125 USH1G FINISHED with n_TFs: 12
# Processing 23/125 KCNIP1
# 23/125 KCNIP1 FINISHED with n_TFs: 9
# Processing 24/125 UNC5C
# 24/125 UNC5C FINISHED with n_TFs: 11
# Processing 25/125 UBA7
# 25/125 UBA7 FINISHED with n_TFs: 13
# Processing 26/125 RAD51B
# 26/125 RAD51B FINISHED with n_TFs: 12
# Processing 27/125 EXT1
# 27/125 EXT1 FINISHED with n_TFs: 27
# Processing 28/125 SHMT2
# 28/125 SHMT2 FINISHED with n_TFs: 21
# Processing 29/125 SYNM
# 29/125 SYNM FINISHED with n_TFs: 17
# Processing 30/125 KCNA4
# 30/125 KCNA4 FINISHED with n_TFs: 8
# Processing 31/125 NLRP10
# 31/125 NLRP10 FINISHED with n_TFs: 8
# Processing 32/125 ZSCAN22
# 32/125 ZSCAN22 FINISHED with n_TFs: 24
# Processing 33/125 C1S
# 33/125 C1S FINISHED with n_TFs: 12
# Processing 34/125 TSHZ2
# 34/125 TSHZ2 FINISHED with n_TFs: 14
# Processing 35/125 KPNA2
# 35/125 KPNA2 FINISHED with n_TFs: 23
# Processing 36/125 LIMK2
# 36/125 LIMK2 FINISHED with n_TFs: 26
# Processing 37/125 SPNS3
# 37/125 SPNS3 FINISHED with n_TFs: 8
# Processing 38/125 SATB1
# 38/125 SATB1 FINISHED with n_TFs: 9
# Processing 39/125 HS3ST4
# 39/125 HS3ST4 FINISHED with n_TFs: 5
# Processing 40/125 SKA2
# 40/125 SKA2 FINISHED with n_TFs: 19
# Processing 41/125 NTM
# 41/125 NTM FINISHED with n_TFs: 5
# Processing 42/125 IGIP
# 42/125 IGIP FINISHED with n_TFs: 2
# Processing 43/125 PAPPA
# 43/125 PAPPA FINISHED with n_TFs: 16
# Processing 44/125 CCDC87
# 44/125 CCDC87 FINISHED with n_TFs: 18
# Processing 45/125 C1ORF116
# 45/125 C1ORF116 FINISHED with n_TFs: 11
# Processing 46/125 PLCXD3
# 46/125 PLCXD3 FINISHED with n_TFs: 5
# Processing 47/125 SLC25A21
# 47/125 SLC25A21 FINISHED with n_TFs: 17
# Processing 48/125 NEB
# 48/125 NEB FINISHED with n_TFs: 9
# Processing 49/125 GPC6
# 49/125 GPC6 FINISHED with n_TFs: 22
# Processing 50/125 ARHGEF37
# 50/125 ARHGEF37 FINISHED with n_TFs: 10
# Processing 51/125 RABIF
# 51/125 RABIF FINISHED with n_TFs: 26
# Processing 52/125 CALN1
# 52/125 CALN1 FINISHED with n_TFs: 14
# Processing 53/125 CCBE1
# 53/125 CCBE1 FINISHED with n_TFs: 10
# TMEM121B not recoverable due to n_TFs = 0
# WARNING: 54/125 TMEM121B not recoverable due to insufficient samples.
# Processing 55/125 ZNF623
# 55/125 ZNF623 FINISHED with n_TFs: 19
# Processing 56/125 LRIT3
# 56/125 LRIT3 FINISHED with n_TFs: 1
# Processing 57/125 GRIN2A
# 57/125 GRIN2A FINISHED with n_TFs: 14
# Processing 58/125 GTF2H2C
# 58/125 GTF2H2C FINISHED with n_TFs: 12
# TENT5C not recoverable due to n_TFs = 0
# WARNING: 59/125 TENT5C not recoverable due to insufficient samples.
# Processing 60/125 ZNRF3
# 60/125 ZNRF3 FINISHED with n_TFs: 16
# Processing 61/125 FAM167B
# 61/125 FAM167B FINISHED with n_TFs: 17
# Processing 62/125 NDUFB1
# 62/125 NDUFB1 FINISHED with n_TFs: 17
# Processing 63/125 MARCH11
# 63/125 MARCH11 FINISHED with n_TFs: 5
# Processing 64/125 PSG9
# 64/125 PSG9 FINISHED with n_TFs: 7
# Processing 65/125 GPR1
# 65/125 GPR1 FINISHED with n_TFs: 7
# Processing 66/125 ALYREF
# 66/125 ALYREF FINISHED with n_TFs: 17
# Processing 67/125 EFHC2
# 67/125 EFHC2 FINISHED with n_TFs: 10
# Processing 68/125 UPP1
# 68/125 UPP1 FINISHED with n_TFs: 28
# Processing 69/125 OPCML
# 69/125 OPCML FINISHED with n_TFs: 9
# Processing 70/125 CMTM4
# 70/125 CMTM4 FINISHED with n_TFs: 15
# ACP7 not recoverable due to n_TFs = 0
# WARNING: 71/125 ACP7 not recoverable due to insufficient samples.
# Processing 72/125 KCTD16
# 72/125 KCTD16 FINISHED with n_TFs: 18
# Processing 73/125 IQGAP3
# 73/125 IQGAP3 FINISHED with n_TFs: 19
# Processing 74/125 ARSI
# 74/125 ARSI FINISHED with n_TFs: 10
# Processing 75/125 DNAH2
# 75/125 DNAH2 FINISHED with n_TFs: 6
# KMT5A not recoverable due to n_TFs = 0
# WARNING: 76/125 KMT5A not recoverable due to insufficient samples.
# Processing 77/125 KCNH8
# 77/125 KCNH8 FINISHED with n_TFs: 14
# Processing 78/125 SMTN
# 78/125 SMTN FINISHED with n_TFs: 18
# Processing 79/125 ST6GALNAC3
# 79/125 ST6GALNAC3 FINISHED with n_TFs: 23
# Processing 80/125 ACTG1
# 80/125 ACTG1 FINISHED with n_TFs: 21
# Processing 81/125 ADAP2
# 81/125 ADAP2 FINISHED with n_TFs: 9
# Processing 82/125 NIPSNAP1
# 82/125 NIPSNAP1 FINISHED with n_TFs: 18
# Processing 83/125 KCNQ3
# 83/125 KCNQ3 FINISHED with n_TFs: 9
# Processing 84/125 CRELD2
# 84/125 CRELD2 FINISHED with n_TFs: 15
# Processing 85/125 PPP1R2
# 85/125 PPP1R2 FINISHED with n_TFs: 22
# Processing 86/125 TSPYL2
# 86/125 TSPYL2 FINISHED with n_TFs: 17
# Processing 87/125 PCDH9
# 87/125 PCDH9 FINISHED with n_TFs: 17
# AC139768.1 not recoverable due to n_TFs = 0
# WARNING: 88/125 AC139768.1 not recoverable due to insufficient samples.
# Processing 89/125 MAML2
# 89/125 MAML2 FINISHED with n_TFs: 25
# Processing 90/125 THAP7
# 90/125 THAP7 FINISHED with n_TFs: 21
# Processing 91/125 KNTC1
# 91/125 KNTC1 FINISHED with n_TFs: 21
# Processing 92/125 PTP4A3
# 92/125 PTP4A3 FINISHED with n_TFs: 8
# Processing 93/125 SOCS3
# 93/125 SOCS3 FINISHED with n_TFs: 26
# Processing 94/125 SLITRK6
# 94/125 SLITRK6 FINISHED with n_TFs: 9
# Processing 95/125 LPAR5
# 95/125 LPAR5 FINISHED with n_TFs: 14
# Processing 96/125 PDE4B
# 96/125 PDE4B FINISHED with n_TFs: 10
# Processing 97/125 NELL2
# 97/125 NELL2 FINISHED with n_TFs: 10
# Processing 98/125 CDCA2
# 98/125 CDCA2 FINISHED with n_TFs: 19
# Processing 99/125 HIST2H2BE
# 99/125 HIST2H2BE FINISHED with n_TFs: 24
# Processing 100/125 ZBTB7C
# 100/125 ZBTB7C FINISHED with n_TFs: 14
# Processing 101/125 PRR16
# 101/125 PRR16 FINISHED with n_TFs: 14
# Processing 102/125 DRD1
# 102/125 DRD1 FINISHED with n_TFs: 10
# Processing 103/125 ARMCX2
# 103/125 ARMCX2 FINISHED with n_TFs: 8
# Processing 104/125 OR6A2
# 104/125 OR6A2 FINISHED with n_TFs: 5
# Processing 105/125 RFX6
# 105/125 RFX6 FINISHED with n_TFs: 6
# Processing 106/125 MAFF
# 106/125 MAFF FINISHED with n_TFs: 21
# Processing 107/125 NELFA
# 107/125 NELFA FINISHED with n_TFs: 18
# Processing 108/125 SLC24A3
# 108/125 SLC24A3 FINISHED with n_TFs: 12
# Processing 109/125 FLRT2
# 109/125 FLRT2 FINISHED with n_TFs: 15
# Processing 110/125 INPP5J
# 110/125 INPP5J FINISHED with n_TFs: 9
# Processing 111/125 TNFAIP2
# 111/125 TNFAIP2 FINISHED with n_TFs: 18
# Processing 112/125 TCN2
# 112/125 TCN2 FINISHED with n_TFs: 16
# Processing 113/125 TARSL2
# 113/125 TARSL2 FINISHED with n_TFs: 13
# Processing 114/125 KPNA7
# 114/125 KPNA7 FINISHED with n_TFs: 12
# Processing 115/125 GPRIN3
# 115/125 GPRIN3 FINISHED with n_TFs: 11
# Processing 116/125 KRT6B
# 116/125 KRT6B FINISHED with n_TFs: 3
# Processing 117/125 ROR1
# 117/125 ROR1 FINISHED with n_TFs: 17
# Processing 118/125 PRKG1
# 118/125 PRKG1 FINISHED with n_TFs: 11
# Processing 119/125 AHNAK2
# 119/125 AHNAK2 FINISHED with n_TFs: 14
# Processing 120/125 OLFML2A
# 120/125 OLFML2A FINISHED with n_TFs: 11
# Processing 121/125 LMLN
# 121/125 LMLN FINISHED with n_TFs: 17
# Processing 122/125 SHC4
# 122/125 SHC4 FINISHED with n_TFs: 16
# Processing 123/125 KRT79
# 123/125 KRT79 FINISHED with n_TFs: 10
# Processing 124/125 ZFP36L1
# 124/125 ZFP36L1 FINISHED with n_TFs: 28
# Processing 0/125 B4GALNT2
# 0/125 B4GALNT2 FINISHED with n_TFs: 11
# Processing 1/125 ZNF646
# 1/125 ZNF646 FINISHED with n_TFs: 18
# Processing 2/125 RHEBL1
# 2/125 RHEBL1 FINISHED with n_TFs: 21
# Processing 3/125 TUBA1A
# 3/125 TUBA1A FINISHED with n_TFs: 22
# Processing 4/125 TMC4
# 4/125 TMC4 FINISHED with n_TFs: 14
# Processing 5/125 ZNF283
# 5/125 ZNF283 FINISHED with n_TFs: 10
# Processing 6/125 ZNF558
# 6/125 ZNF558 FINISHED with n_TFs: 6
# Processing 7/125 HID1
# 7/125 HID1 FINISHED with n_TFs: 12
# Processing 8/125 ABCA3
# 8/125 ABCA3 FINISHED with n_TFs: 21
# Processing 9/125 NLRC3
# 9/125 NLRC3 FINISHED with n_TFs: 10
# Processing 10/125 SLC3A2
# 10/125 SLC3A2 FINISHED with n_TFs: 25
# Processing 11/125 TRANK1
# 11/125 TRANK1 FINISHED with n_TFs: 9
# Processing 12/125 SCARA5
# 12/125 SCARA5 FINISHED with n_TFs: 13
# Processing 13/125 FAM83B
# 13/125 FAM83B FINISHED with n_TFs: 7
# Processing 14/125 DDIT4
# 14/125 DDIT4 FINISHED with n_TFs: 31
# Processing 15/125 GNG4
# 15/125 GNG4 FINISHED with n_TFs: 19
# Processing 16/125 HIST1H1E
# 16/125 HIST1H1E FINISHED with n_TFs: 24
# Processing 17/125 MFSD2A
# 17/125 MFSD2A FINISHED with n_TFs: 15
# Processing 18/125 CDC40
# 18/125 CDC40 FINISHED with n_TFs: 19
# Processing 19/125 HR
# 19/125 HR FINISHED with n_TFs: 12
# Processing 20/125 LGI3
# 20/125 LGI3 FINISHED with n_TFs: 7
# Processing 21/125 POLR3D
# 21/125 POLR3D FINISHED with n_TFs: 17
# CAVIN2 not recoverable due to n_TFs = 0
# WARNING: 22/125 CAVIN2 not recoverable due to insufficient samples.
# Processing 23/125 SERINC2
# 23/125 SERINC2 FINISHED with n_TFs: 9
# Processing 24/125 MYL1
# 24/125 MYL1 FINISHED with n_TFs: 7
# Processing 25/125 COL3A1
# 25/125 COL3A1 FINISHED with n_TFs: 6
# Processing 26/125 SLC20A2
# 26/125 SLC20A2 FINISHED with n_TFs: 22
# Processing 27/125 ZNF30
# 27/125 ZNF30 FINISHED with n_TFs: 16
# Processing 28/125 FAM84B
# 28/125 FAM84B FINISHED with n_TFs: 13
# Processing 29/125 LDLRAD4
# 29/125 LDLRAD4 FINISHED with n_TFs: 9
# Processing 30/125 IL7R
# 30/125 IL7R FINISHED with n_TFs: 14
# Processing 31/125 LRP1B
# 31/125 LRP1B FINISHED with n_TFs: 8
# Processing 32/125 TET2
# 32/125 TET2 FINISHED with n_TFs: 18
# Processing 33/125 INPP5D
# 33/125 INPP5D FINISHED with n_TFs: 21
# Processing 34/125 SPRY3
# 34/125 SPRY3 FINISHED with n_TFs: 11
# ATP5ME not recoverable due to n_TFs = 0
# WARNING: 35/125 ATP5ME not recoverable due to insufficient samples.
# Processing 36/125 IRS1
# 36/125 IRS1 FINISHED with n_TFs: 25
# Processing 37/125 HSPBAP1
# 37/125 HSPBAP1 FINISHED with n_TFs: 22
# Processing 38/125 AFAP1L2
# 38/125 AFAP1L2 FINISHED with n_TFs: 10
# Processing 39/125 MN1
# 39/125 MN1 FINISHED with n_TFs: 11
# Processing 40/125 RAB3B
# 40/125 RAB3B FINISHED with n_TFs: 7
# Processing 41/125 EFNA1
# 41/125 EFNA1 FINISHED with n_TFs: 25
# Processing 42/125 SH3TC2
# 42/125 SH3TC2 FINISHED with n_TFs: 13
# Processing 43/125 ADRB2
# 43/125 ADRB2 FINISHED with n_TFs: 13
# Processing 44/125 HSPB3
# 44/125 HSPB3 FINISHED with n_TFs: 10
# Processing 45/125 STK32A
# 45/125 STK32A FINISHED with n_TFs: 10
# Processing 46/125 IL1RAPL1
# 46/125 IL1RAPL1 FINISHED with n_TFs: 9
# MINAR1 not recoverable due to n_TFs = 0
# WARNING: 47/125 MINAR1 not recoverable due to insufficient samples.
# Processing 48/125 PTAFR
# 48/125 PTAFR FINISHED with n_TFs: 16
# Processing 49/125 CXCL8
# 49/125 CXCL8 FINISHED with n_TFs: 12
# Processing 50/125 RASSF6
# 50/125 RASSF6 FINISHED with n_TFs: 14
# Processing 51/125 COL22A1
# 51/125 COL22A1 FINISHED with n_TFs: 9
# Processing 52/125 SDC2
# 52/125 SDC2 FINISHED with n_TFs: 11
# Processing 53/125 ZNF280A
# 53/125 ZNF280A FINISHED with n_TFs: 13
# Processing 54/125 CLIC3
# 54/125 CLIC3 FINISHED with n_TFs: 9
# Processing 55/125 PROKR1
# 55/125 PROKR1 FINISHED with n_TFs: 15
# Processing 56/125 LUZP1
# 56/125 LUZP1 FINISHED with n_TFs: 24
# Processing 57/125 BUB1
# 57/125 BUB1 FINISHED with n_TFs: 16
# Processing 58/125 AGPAT2
# 58/125 AGPAT2 FINISHED with n_TFs: 14
# Processing 59/125 MT1E
# 59/125 MT1E FINISHED with n_TFs: 8
# Processing 60/125 BTD
# 60/125 BTD FINISHED with n_TFs: 22
# MUC3A not recoverable due to n_TFs = 0
# WARNING: 61/125 MUC3A not recoverable due to insufficient samples.
# Processing 62/125 ITGAM
# 62/125 ITGAM FINISHED with n_TFs: 10
# Processing 63/125 TM4SF1
# 63/125 TM4SF1 FINISHED with n_TFs: 12
# Processing 64/125 FRMPD4
# 64/125 FRMPD4 FINISHED with n_TFs: 7
# Processing 65/125 MYO7B
# 65/125 MYO7B FINISHED with n_TFs: 3
# Processing 66/125 TMEM154
# 66/125 TMEM154 FINISHED with n_TFs: 18
# Processing 67/125 ZPLD1
# 67/125 ZPLD1 FINISHED with n_TFs: 4
# Processing 68/125 RNF150
# 68/125 RNF150 FINISHED with n_TFs: 17
# Processing 69/125 ANKK1
# 69/125 ANKK1 FINISHED with n_TFs: 9
# Processing 70/125 PWWP2A
# 70/125 PWWP2A FINISHED with n_TFs: 17
# Processing 71/125 FAXDC2
# 71/125 FAXDC2 FINISHED with n_TFs: 9
# Processing 72/125 SLN
# 72/125 SLN FINISHED with n_TFs: 9
# Processing 73/125 CDK1
# 73/125 CDK1 FINISHED with n_TFs: 19
# Processing 74/125 FRMPD2
# 74/125 FRMPD2 FINISHED with n_TFs: 5
# Processing 75/125 FOS
# 75/125 FOS FINISHED with n_TFs: 22
# Processing 76/125 CST1
# 76/125 CST1 FINISHED with n_TFs: 2
# Processing 77/125 TCAF2
# 77/125 TCAF2 FINISHED with n_TFs: 8
# Processing 78/125 SEMA3E
# 78/125 SEMA3E FINISHED with n_TFs: 4
# Processing 79/125 KRT8
# 79/125 KRT8 FINISHED with n_TFs: 20
# Processing 80/125 ADORA2B
# 80/125 ADORA2B FINISHED with n_TFs: 20
# Processing 81/125 METTL7B
# 81/125 METTL7B FINISHED with n_TFs: 16
# Processing 82/125 KRT75
# 82/125 KRT75 FINISHED with n_TFs: 6
# Processing 83/125 LONRF2
# 83/125 LONRF2 FINISHED with n_TFs: 12
# Processing 84/125 ZNF16
# 84/125 ZNF16 FINISHED with n_TFs: 6
# Processing 85/125 GPR27
# 85/125 GPR27 FINISHED with n_TFs: 9
# Processing 86/125 KBTBD2
# 86/125 KBTBD2 FINISHED with n_TFs: 21
# Processing 87/125 OSCAR
# 87/125 OSCAR FINISHED with n_TFs: 16
# Processing 88/125 PKHD1
# 88/125 PKHD1 FINISHED with n_TFs: 11
# Processing 89/125 HAS2
# 89/125 HAS2 FINISHED with n_TFs: 19
# Processing 90/125 PDGFD
# 90/125 PDGFD FINISHED with n_TFs: 5
# Processing 91/125 PLAC1
# 91/125 PLAC1 FINISHED with n_TFs: 5
# Processing 92/125 HS6ST2
# 92/125 HS6ST2 FINISHED with n_TFs: 8
# Processing 93/125 TMEM37
# 93/125 TMEM37 FINISHED with n_TFs: 21
# Processing 94/125 SHCBP1
# 94/125 SHCBP1 FINISHED with n_TFs: 14
# Processing 95/125 KCNK3
# 95/125 KCNK3 FINISHED with n_TFs: 12
# Processing 96/125 CHD7
# 96/125 CHD7 FINISHED with n_TFs: 18
# Processing 97/125 ESCO2
# 97/125 ESCO2 FINISHED with n_TFs: 20
# Processing 98/125 KRT15
# 98/125 KRT15 FINISHED with n_TFs: 10
# Processing 99/125 CLCN5
# 99/125 CLCN5 FINISHED with n_TFs: 15
# Processing 100/125 KCND3
# 100/125 KCND3 FINISHED with n_TFs: 16
# Processing 101/125 KSR2
# 101/125 KSR2 FINISHED with n_TFs: 11
# Processing 102/125 MCC
# 102/125 MCC FINISHED with n_TFs: 19
# Processing 103/125 POLR1C
# 103/125 POLR1C FINISHED with n_TFs: 17
# Processing 104/125 NLRP5
# 104/125 NLRP5 FINISHED with n_TFs: 4
# Processing 105/125 LRRC8D
# 105/125 LRRC8D FINISHED with n_TFs: 24
# Processing 106/125 COL24A1
# 106/125 COL24A1 FINISHED with n_TFs: 10
# Processing 107/125 ZNF584
# 107/125 ZNF584 FINISHED with n_TFs: 18
# Processing 108/125 ENC1
# 108/125 ENC1 FINISHED with n_TFs: 24
# Processing 109/125 ATF7IP
# 109/125 ATF7IP FINISHED with n_TFs: 23
# Processing 110/125 VAT1L
# 110/125 VAT1L FINISHED with n_TFs: 6
# Processing 111/125 TMEM51
# 111/125 TMEM51 FINISHED with n_TFs: 20
# Processing 112/125 GATM
# 112/125 GATM FINISHED with n_TFs: 13
# Processing 113/125 CTPS1
# 113/125 CTPS1 FINISHED with n_TFs: 13
# Processing 114/125 ZNF540
# 114/125 ZNF540 FINISHED with n_TFs: 5
# Processing 115/125 RRM2
# 115/125 RRM2 FINISHED with n_TFs: 28
# Processing 116/125 C3AR1
# 116/125 C3AR1 FINISHED with n_TFs: 13
# Processing 117/125 KLF17
# 117/125 KLF17 FINISHED with n_TFs: 6
# Processing 118/125 CYP4F11
# 118/125 CYP4F11 FINISHED with n_TFs: 16
# Processing 119/125 SCG2
# 119/125 SCG2 FINISHED with n_TFs: 13
# Processing 120/125 SYNPO
# 120/125 SYNPO FINISHED with n_TFs: 14
# Processing 121/125 ZNF554
# 121/125 ZNF554 FINISHED with n_TFs: 18
# Processing 122/125 GAP43
# 122/125 GAP43 FINISHED with n_TFs: 12
# Processing 123/125 LRRC15
# 123/125 LRRC15 FINISHED with n_TFs: 9
# Processing 124/125 KRCC1
# 124/125 KRCC1 FINISHED with n_TFs: 18
#     finished (0:41:32) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# True

# %%
losses = adata.varm["loss"].copy()
losses[np.isnan(losses)] = 1e6
adata.var["min_loss"] = losses.min(1)

n_cells = adata.shape[0]
expanded_scaling_y = np.expand_dims(np.array(adata.var["fit_scaling_y"]), 0).repeat(n_cells, axis=0)
adata.layers["velocity"] = adata.layers["velo_hat"] / expanded_scaling_y

adata.write(DATA_DIR / "cell_cycle" / "TFvelo_cellcycle.h5ad")
