# %% [markdown]
# # Calculate velocity and latent time using TFvelo
#
# Notebook benchmarks velocity and latent time inference using TFvelo on dyngen-generated data.

# %% [markdown]
# ## Library imports

# %%
import pandas as pd
import os

from sklearn.metrics import roc_auc_score
import anndata as ad
import scvelo as scv
from cellrank.kernels import VelocityKernel

import sys

sys.path.insert(0, "/lustre/groups/ml01/workspace/yifan.chen/TFvelo/")
import TFvelo as TFv
import numpy as np
import torch
import scipy

from rgv_tools import DATA_DIR
from rgv_tools.benchmarking import get_time_correlation, get_velocity_correlation, set_output

# %% [markdown]
# ## Function definitions

# %%
def run_TFvelo(adata):
    """TFvelo pipeline."""
    adata.X = adata.X.toarray()
    n_gene = adata.shape[1]
    adata.varm["TFs"] = np.full([n_gene, n_gene], "blank")
    adata.varm["TFs"] = adata.varm["TFs"].astype("U10")

    adata.varm["TFs_id"] = np.full([n_gene, n_gene], -1)
    adata.varm["TFs_times"] = np.full([n_gene, n_gene], 0)
    adata.varm["TFs_correlation"] = np.full([n_gene, n_gene], 0.0)
    adata.varm["knockTF_Log2FC"] = np.full([n_gene, n_gene], 0.0)
    adata.var["n_TFs"] = np.zeros(n_gene, dtype=int)

    gene_names = adata.var_names.tolist()  # all genes as targets
    all_TFs = list(adata.var_names[adata.var["is_tf"]])  # select TFs

    for TF_name in all_TFs:
        TF_idx = gene_names.index(TF_name)
        TF_expression = np.ravel(adata[:, TF_name].X)

        for target in gene_names:
            target_idx = gene_names.index(target)
            if target == TF_name:
                continue

            if TF_name in adata.varm["TFs"][target_idx]:
                ii = list(adata.varm["TFs"][target_idx]).index(TF_name)
                adata.varm["TFs_times"][target_idx, ii] += 1
                continue
            target_expression = np.ravel(adata[:, target].X)
            flag = (TF_expression > 0) & (target_expression > 0)  # consider all possible regulation
            if flag.sum() < 2:
                correlation = 0
            else:
                correlation, _ = scipy.stats.spearmanr(target_expression[flag], TF_expression[flag])

            tmp_n_TF = adata.var["n_TFs"][target_idx]
            adata.varm["TFs"][target_idx][tmp_n_TF] = TF_name
            adata.varm["TFs_id"][target_idx][tmp_n_TF] = TF_idx
            adata.varm["TFs_times"][target_idx, tmp_n_TF] = 1
            adata.varm["TFs_correlation"][target_idx, tmp_n_TF] = correlation
            adata.var["n_TFs"][target_idx] += 1

    TFv.tl.recover_dynamics(
        adata,
        n_jobs=64,
        max_iter=20,
        var_names="all",
        WX_method="lsq_linear",
        WX_thres=20,
        n_top_genes=adata.shape[1],
        fit_scaling=True,
        use_raw=0,
        init_weight_method="ones",
        n_time_points=1000,
    )
    n_cells = adata.shape[0]
    expanded_scaling_y = np.expand_dims(np.array(adata.var["fit_scaling_y"]), 0).repeat(n_cells, axis=0)
    adata.layers["velocity"] = adata.layers["velo_hat"] / expanded_scaling_y
    return adata

# %% [markdown]
# ## Constants

# %%
DATASET = "dyngen"

# %%
COMPLEXITY = "complexity_1"

# %%
SAVE_DATA = True
if SAVE_DATA:
    (DATA_DIR / DATASET / COMPLEXITY / "results").mkdir(parents=True, exist_ok=True)

# %%
SAVE_DATASETS = True
if SAVE_DATASETS:
    (DATA_DIR / DATASET / COMPLEXITY / "trained_tfvelo").mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Velocity pipeline

# %%
velocity_correlation_all = []
velocity_correlation = []
grn_correlation = []

cnt = 0
for filename in (DATA_DIR / DATASET / COMPLEXITY / "processed").iterdir():
    torch.cuda.empty_cache()
    if filename.suffix != ".zarr":
        continue

    simulation_id = int(filename.stem.removeprefix("simulation_"))
    print(f"Run {cnt}, dataset {simulation_id}.")

    adata = ad.io.read_zarr(filename)

    if "spliced" in adata.layers:
        adata.layers["total"] = adata.layers["spliced"].todense() + adata.layers["unspliced"].todense()
    elif "new" in adata.layers:
        adata.layers["total"] = np.array(adata.layers["total"].todense())
    else:
        adata.layers["total"] = adata.X
    adata.layers["total_raw"] = adata.layers["total"].copy()

    TFv.pp.moments(adata, n_pcs=None, n_neighbors=None)

    adata = run_TFvelo(adata)

    # save data
    adata.write_zarr(DATA_DIR / DATASET / COMPLEXITY / "trained_tfvelo" / f"trained_{simulation_id}.zarr")

    velo_corr = get_velocity_correlation(
        ground_truth=adata.layers["true_velocity"], estimated=adata.layers["velocity"], aggregation=None
    )

    velocity_correlation_all.append(velo_corr)

    velo_corr = np.array(velo_corr)

    velocity_correlation.append(np.mean(velo_corr[~np.isnan(velo_corr)]))

    grn_true = adata.uns["true_skeleton"]
    grn_sc_true = adata.uns["true_sc_grn"]

    grn_estimate = pd.DataFrame(0, index=adata.var_names, columns=adata.var_names)
    grn_estimate.loc[:, adata.var_names[adata.var["is_tf"]]] = adata.varm["fit_weights_final"]
    grn_estimate = np.array(grn_estimate)

    grn_auroc = []
    for cell_id in range(adata.n_obs):
        ground_truth = grn_sc_true[:, :, cell_id]

        if ground_truth.sum() > 0:
            ground_truth = ground_truth.T[np.array(grn_true.T) == 1]
            ground_truth[ground_truth != 0] = 1

            estimated = grn_estimate[np.array(grn_true.T) == 1]
            estimated = np.abs(estimated)

            number = min(10000, len(ground_truth))
            estimated, index = torch.topk(torch.tensor(estimated), number)

            grn_auroc.append(roc_auc_score(ground_truth[index], estimated))

    grn_correlation.append(np.mean(grn_auroc))

    cnt += 1
# Out:
# Run 0, dataset 29.
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'M_total', moments of total abundances (adata.layers)
# recovering dynamics (using 64/128 cores)
#   0%|          | 0/362 [00:00<?, ?gene/s]
# Processing 0/6 Target17
# 0/6 Target17 FINISHED with n_TFs: 25
# Processing 1/6 Target26
# 1/6 Target26 FINISHED with n_TFs: 25
# Processing 2/6 Target32
# 2/6 Target32 FINISHED with n_TFs: 25
# Processing 3/6 Target36
# 3/6 Target36 FINISHED with n_TFs: 25
# Processing 4/6 Target43
# 4/6 Target43 FINISHED with n_TFs: 25
# Processing 5/6 Target46
# 5/6 Target46 FINISHED with n_TFs: 25
# Processing 0/6 C1_TF1
# 0/6 C1_TF1 FINISHED with n_TFs: 24
# Processing 1/6 C1_TF2
# 1/6 C1_TF2 FINISHED with n_TFs: 24
# Processing 2/6 C2_TF1
# 2/6 C2_TF1 FINISHED with n_TFs: 24
# Processing 3/6 C3_TF2
# 3/6 C3_TF2 FINISHED with n_TFs: 24
# Processing 4/6 C4_TF1
# 4/6 C4_TF1 FINISHED with n_TFs: 24
# Processing 5/6 C4_TF2
# 5/6 C4_TF2 FINISHED with n_TFs: 24
# Processing 0/6 A5_TF1
# 0/6 A5_TF1 FINISHED with n_TFs: 24
# Processing 1/6 B1_TF1
# 1/6 B1_TF1 FINISHED with n_TFs: 24
# Processing 2/6 B2_TF1
# 2/6 B2_TF1 FINISHED with n_TFs: 24
# Processing 3/6 B2_TF2
# 3/6 B2_TF2 FINISHED with n_TFs: 24
# Processing 4/6 B4_TF1
# 4/6 B4_TF1 FINISHED with n_TFs: 24
# Processing 5/6 B5_TF1
# 5/6 B5_TF1 FINISHED with n_TFs: 24
# Processing 0/6 Target48
# 0/6 Target48 FINISHED with n_TFs: 25
# Processing 1/6 Target57
# 1/6 Target57 FINISHED with n_TFs: 25
# Processing 2/6 Target58
# 2/6 Target58 FINISHED with n_TFs: 25
# Processing 3/6 Target62
# 3/6 Target62 FINISHED with n_TFs: 25
# Processing 4/6 Target64
# 4/6 Target64 FINISHED with n_TFs: 25
# Processing 5/6 Target69
# 5/6 Target69 FINISHED with n_TFs: 25
# Processing 0/6 Target74
# 0/6 Target74 FINISHED with n_TFs: 25
# Processing 1/6 Target75
# 1/6 Target75 FINISHED with n_TFs: 25
# Processing 2/6 Target80
# 2/6 Target80 FINISHED with n_TFs: 25
# Processing 3/6 Target81
# 3/6 Target81 FINISHED with n_TFs: 25
# Processing 4/6 Target82
# 4/6 Target82 FINISHED with n_TFs: 25
# Processing 5/6 Target83
# 5/6 Target83 FINISHED with n_TFs: 25
# Processing 0/6 Target142
# 0/6 Target142 FINISHED with n_TFs: 25
# Processing 1/6 Target143
# 1/6 Target143 FINISHED with n_TFs: 25
# Processing 2/6 Target144
# 2/6 Target144 FINISHED with n_TFs: 25
# Processing 3/6 Target145
# 3/6 Target145 FINISHED with n_TFs: 25
# Processing 4/6 Target149
# 4/6 Target149 FINISHED with n_TFs: 25
# Processing 5/6 Target154
# 5/6 Target154 FINISHED with n_TFs: 25
# Processing 0/6 Target86
# 0/6 Target86 FINISHED with n_TFs: 25
# Processing 1/6 Target90
# 1/6 Target90 FINISHED with n_TFs: 25
# Processing 2/6 Target102
# 2/6 Target102 FINISHED with n_TFs: 25
# Processing 3/6 Target103
# 3/6 Target103 FINISHED with n_TFs: 25
# Processing 4/6 Target105
# 4/6 Target105 FINISHED with n_TFs: 25
# Processing 5/6 Target106
# 5/6 Target106 FINISHED with n_TFs: 25
# Processing 0/6 Target116
# 0/6 Target116 FINISHED with n_TFs: 25
# Processing 1/6 Target118
# 1/6 Target118 FINISHED with n_TFs: 25
# Processing 2/6 Target119
# 2/6 Target119 FINISHED with n_TFs: 25
# Processing 3/6 Target121
# 3/6 Target121 FINISHED with n_TFs: 25
# Processing 4/6 Target129
# 4/6 Target129 FINISHED with n_TFs: 25
# Processing 5/6 Target131
# 5/6 Target131 FINISHED with n_TFs: 25
# Processing 0/6 Target132
# 0/6 Target132 FINISHED with n_TFs: 25
# Processing 1/6 Target133
# 1/6 Target133 FINISHED with n_TFs: 25
# Processing 2/6 Target134
# 2/6 Target134 FINISHED with n_TFs: 25
# Processing 3/6 Target136
# 3/6 Target136 FINISHED with n_TFs: 25
# Processing 4/6 Target137
# 4/6 Target137 FINISHED with n_TFs: 25
# Processing 5/6 Target141
# 5/6 Target141 FINISHED with n_TFs: 25
# Processing 0/6 D4_TF1
# 0/6 D4_TF1 FINISHED with n_TFs: 24
# Processing 1/6 Target3
# 1/6 Target3 FINISHED with n_TFs: 25
# Processing 2/6 Target8
# 2/6 Target8 FINISHED with n_TFs: 25
# Processing 3/6 Target9
# 3/6 Target9 FINISHED with n_TFs: 25
# Processing 4/6 Target11
# 4/6 Target11 FINISHED with n_TFs: 25
# Processing 5/6 Target15
# 5/6 Target15 FINISHED with n_TFs: 25
# Processing 0/6 C5_TF1
# 0/6 C5_TF1 FINISHED with n_TFs: 24
# Processing 1/6 C8_TF1
# 1/6 C8_TF1 FINISHED with n_TFs: 24
# Processing 2/6 C11_TF1
# 2/6 C11_TF1 FINISHED with n_TFs: 24
# Processing 3/6 C11_TF2
# 3/6 C11_TF2 FINISHED with n_TFs: 24
# Processing 4/6 C12_TF1
# 4/6 C12_TF1 FINISHED with n_TFs: 24
# Processing 5/6 C13_TF1
# 5/6 C13_TF1 FINISHED with n_TFs: 24
# Processing 0/6 Target107
# 0/6 Target107 FINISHED with n_TFs: 25
# Processing 1/6 Target110
# 1/6 Target110 FINISHED with n_TFs: 25
# Processing 2/6 Target111
# 2/6 Target111 FINISHED with n_TFs: 25
# Processing 3/6 Target112
# 3/6 Target112 FINISHED with n_TFs: 25
# Processing 4/6 Target114
# 4/6 Target114 FINISHED with n_TFs: 25
# Processing 5/6 Target115
# 5/6 Target115 FINISHED with n_TFs: 25
# Processing 0/6 C14_TF1
# 0/6 C14_TF1 FINISHED with n_TFs: 24
# Processing 1/6 C14_TF2
# 1/6 C14_TF2 FINISHED with n_TFs: 24
# Processing 2/6 D1_TF1
# 2/6 D1_TF1 FINISHED with n_TFs: 24
# Processing 3/6 D1_TF2
# 3/6 D1_TF2 FINISHED with n_TFs: 24
# Processing 4/6 D2_TF1
# 4/6 D2_TF1 FINISHED with n_TFs: 24
# Processing 5/6 D3_TF1
# 5/6 D3_TF1 FINISHED with n_TFs: 24
#     finished (0:13:37) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# Run 1, dataset 14.
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'M_total', moments of total abundances (adata.layers)
# recovering dynamics (using 64/128 cores)
#   0%|          | 0/664 [00:00<?, ?gene/s]
# Processing 0/6 Target356
# 0/6 Target356 FINISHED with n_TFs: 25
# Processing 1/6 Target357
# 1/6 Target357 FINISHED with n_TFs: 25
# Processing 2/6 Target359
# 2/6 Target359 FINISHED with n_TFs: 25
# Processing 3/6 Target360
# 3/6 Target360 FINISHED with n_TFs: 25
# Processing 4/6 Target361
# 4/6 Target361 FINISHED with n_TFs: 25
# Processing 5/6 Target362
# 5/6 Target362 FINISHED with n_TFs: 25
# Processing 0/6 Target302
# 0/6 Target302 FINISHED with n_TFs: 25
# Processing 1/6 Target305
# 1/6 Target305 FINISHED with n_TFs: 25
# Processing 2/6 Target306
# 2/6 Target306 FINISHED with n_TFs: 25
# Processing 3/6 Target308
# 3/6 Target308 FINISHED with n_TFs: 25
# Processing 4/6 Target310
# 4/6 Target310 FINISHED with n_TFs: 25
# Processing 5/6 Target311
# 5/6 Target311 FINISHED with n_TFs: 25
# Processing 0/6 Target168
# 0/6 Target168 FINISHED with n_TFs: 25
# Processing 1/6 Target169
# 1/6 Target169 FINISHED with n_TFs: 25
# Processing 2/6 Target170
# 2/6 Target170 FINISHED with n_TFs: 25
# Processing 3/6 Target172
# 3/6 Target172 FINISHED with n_TFs: 25
# Processing 4/6 Target173
# 4/6 Target173 FINISHED with n_TFs: 25
# Processing 5/6 Target175
# 5/6 Target175 FINISHED with n_TFs: 25
# Processing 0/6 Target364
# 0/6 Target364 FINISHED with n_TFs: 25
# Processing 1/6 Target365
# 1/6 Target365 FINISHED with n_TFs: 25
# Processing 2/6 Target366
# 2/6 Target366 FINISHED with n_TFs: 25
# Processing 3/6 Target367
# 3/6 Target367 FINISHED with n_TFs: 25
# Processing 4/6 Target368
# 4/6 Target368 FINISHED with n_TFs: 25
# Processing 5/6 Target369
# 5/6 Target369 FINISHED with n_TFs: 25
# Processing 0/6 Target274
# 0/6 Target274 FINISHED with n_TFs: 25
# Processing 1/6 Target275
# 1/6 Target275 FINISHED with n_TFs: 25
# Processing 2/6 Target277
# 2/6 Target277 FINISHED with n_TFs: 25
# Processing 3/6 Target278
# 3/6 Target278 FINISHED with n_TFs: 25
# Processing 4/6 Target279
# 4/6 Target279 FINISHED with n_TFs: 25
# Processing 5/6 Target280
# 5/6 Target280 FINISHED with n_TFs: 25
# Processing 0/6 Target424
# 0/6 Target424 FINISHED with n_TFs: 25
# Processing 1/6 Target426
# 1/6 Target426 FINISHED with n_TFs: 25
# Processing 2/6 Target427
# 2/6 Target427 FINISHED with n_TFs: 25
# Processing 3/6 Target430
# 3/6 Target430 FINISHED with n_TFs: 25
# Processing 4/6 Target431
# 4/6 Target431 FINISHED with n_TFs: 25
# Processing 5/6 Target432
# 5/6 Target432 FINISHED with n_TFs: 25
# Processing 0/6 Target213
# 0/6 Target213 FINISHED with n_TFs: 25
# Processing 1/6 Target215
# 1/6 Target215 FINISHED with n_TFs: 25
# Processing 2/6 Target217
# 2/6 Target217 FINISHED with n_TFs: 25
# Processing 3/6 Target221
# 3/6 Target221 FINISHED with n_TFs: 25
# Processing 4/6 Target222
# 4/6 Target222 FINISHED with n_TFs: 25
# Processing 5/6 Target224
# 5/6 Target224 FINISHED with n_TFs: 25
# Processing 0/6 Target246
# 0/6 Target246 FINISHED with n_TFs: 25
# Processing 1/6 Target251
# 1/6 Target251 FINISHED with n_TFs: 25
# Processing 2/6 Target264
# 2/6 Target264 FINISHED with n_TFs: 25
# Processing 3/6 Target265
# 3/6 Target265 FINISHED with n_TFs: 25
# Processing 4/6 Target266
# 4/6 Target266 FINISHED with n_TFs: 25
# Processing 5/6 Target267
# 5/6 Target267 FINISHED with n_TFs: 25
# Processing 0/6 Target226
# 0/6 Target226 FINISHED with n_TFs: 25
# Processing 1/6 Target227
# 1/6 Target227 FINISHED with n_TFs: 25
# Processing 2/6 Target228
# 2/6 Target228 FINISHED with n_TFs: 25
# Processing 3/6 Target230
# 3/6 Target230 FINISHED with n_TFs: 25
# Processing 4/6 Target234
# 4/6 Target234 FINISHED with n_TFs: 25
# Processing 5/6 Target239
# 5/6 Target239 FINISHED with n_TFs: 25
# Processing 0/6 Target268
# 0/6 Target268 FINISHED with n_TFs: 25
# Processing 1/6 Target269
# 1/6 Target269 FINISHED with n_TFs: 25
# Processing 2/6 Target270
# 2/6 Target270 FINISHED with n_TFs: 25
# Processing 3/6 Target271
# 3/6 Target271 FINISHED with n_TFs: 25
# Processing 4/6 Target272
# 4/6 Target272 FINISHED with n_TFs: 25
# Processing 5/6 Target273
# 5/6 Target273 FINISHED with n_TFs: 25
# Processing 0/6 Target409
# 0/6 Target409 FINISHED with n_TFs: 25
# Processing 1/6 Target410
# 1/6 Target410 FINISHED with n_TFs: 25
# Processing 2/6 Target412
# 2/6 Target412 FINISHED with n_TFs: 25
# Processing 3/6 Target413
# 3/6 Target413 FINISHED with n_TFs: 25
# Processing 4/6 Target414
# 4/6 Target414 FINISHED with n_TFs: 25
# Processing 5/6 Target416
# 5/6 Target416 FINISHED with n_TFs: 25
# Processing 0/6 Target376
# 0/6 Target376 FINISHED with n_TFs: 25
# Processing 1/6 Target377
# 1/6 Target377 FINISHED with n_TFs: 25
# Processing 2/6 Target378
# 2/6 Target378 FINISHED with n_TFs: 25
# Processing 3/6 Target379
# 3/6 Target379 FINISHED with n_TFs: 25
# Processing 4/6 Target381
# 4/6 Target381 FINISHED with n_TFs: 25
# Processing 5/6 Target382
# 5/6 Target382 FINISHED with n_TFs: 25
# Processing 0/5 Target770
# 0/5 Target770 FINISHED with n_TFs: 25
# Processing 1/5 Target771
# 1/5 Target771 FINISHED with n_TFs: 25
# Processing 2/5 Target772
# 2/5 Target772 FINISHED with n_TFs: 25
# Processing 3/5 Target774
# 3/5 Target774 FINISHED with n_TFs: 25
# Processing 4/5 Target775
# 4/5 Target775 FINISHED with n_TFs: 25
# Processing 0/11 C10_TF1
# 0/11 C10_TF1 FINISHED with n_TFs: 41
# Processing 1/11 C11_TF1
# 1/11 C11_TF1 FINISHED with n_TFs: 41
# WARNING: 2/11 C12_TF1 not recoverable due to insufficient samples.
# Processing 3/11 C12_TF2
# 3/11 C12_TF2 FINISHED with n_TFs: 41
# WARNING: 4/11 C13_TF1 not recoverable due to insufficient samples.
# WARNING: 5/11 C14_TF1 not recoverable due to insufficient samples.
# Processing 6/11 D1_TF1
# 6/11 D1_TF1 FINISHED with n_TFs: 41
# Processing 7/11 D2_TF1
# 7/11 D2_TF1 FINISHED with n_TFs: 41
# Processing 8/11 D3_TF1
# 8/11 D3_TF1 FINISHED with n_TFs: 41
# Processing 9/11 D3_TF2
# 9/11 D3_TF2 FINISHED with n_TFs: 41
# Processing 10/11 D4_TF1
# 10/11 D4_TF1 FINISHED with n_TFs: 41
# Processing 0/6 Target207
# 0/6 Target207 FINISHED with n_TFs: 25
# Processing 1/6 Target208
# 1/6 Target208 FINISHED with n_TFs: 25
# Processing 2/6 Target209
# 2/6 Target209 FINISHED with n_TFs: 25
# Processing 3/6 Target210
# 3/6 Target210 FINISHED with n_TFs: 25
# Processing 4/6 Target211
# 4/6 Target211 FINISHED with n_TFs: 25
# Processing 5/6 Target212
# 5/6 Target212 FINISHED with n_TFs: 25
# WARNING: 0/10 Target334 not recoverable due to insufficient samples.
# WARNING: 1/10 Target335 not recoverable due to insufficient samples.
# WARNING: 2/10 Target336 not recoverable due to insufficient samples.
# WARNING: 3/10 Target337 not recoverable due to insufficient samples.
# WARNING: 4/10 Target338 not recoverable due to insufficient samples.
# WARNING: 5/10 Target339 not recoverable due to insufficient samples.
# WARNING: 6/10 Target340 not recoverable due to insufficient samples.
# Processing 7/10 Target341
# 7/10 Target341 FINISHED with n_TFs: 42
# Processing 8/10 Target342
# 8/10 Target342 FINISHED with n_TFs: 42
# WARNING: 9/10 Target343 not recoverable due to insufficient samples.
# Processing 0/6 Target161
# 0/6 Target161 FINISHED with n_TFs: 25
# Processing 1/6 Target162
# 1/6 Target162 FINISHED with n_TFs: 25
# Processing 2/6 Target163
# 2/6 Target163 FINISHED with n_TFs: 25
# Processing 3/6 Target165
# 3/6 Target165 FINISHED with n_TFs: 25
# Processing 4/6 Target166
# 4/6 Target166 FINISHED with n_TFs: 25
# Processing 5/6 Target167
# 5/6 Target167 FINISHED with n_TFs: 25
# WARNING: 0/10 Target292 not recoverable due to insufficient samples.
# WARNING: 1/10 Target293 not recoverable due to insufficient samples.
# WARNING: 2/10 Target294 not recoverable due to insufficient samples.
# Processing 3/10 Target295
# 3/10 Target295 FINISHED with n_TFs: 42
# WARNING: 4/10 Target296 not recoverable due to insufficient samples.
# WARNING: 5/10 Target297 not recoverable due to insufficient samples.
# WARNING: 6/10 Target298 not recoverable due to insufficient samples.
# WARNING: 7/10 Target299 not recoverable due to insufficient samples.
# WARNING: 8/10 Target300 not recoverable due to insufficient samples.
# Processing 9/10 Target301
# 9/10 Target301 FINISHED with n_TFs: 42
# WARNING: 0/10 Target720 not recoverable due to insufficient samples.
# WARNING: 1/10 Target721 not recoverable due to insufficient samples.
# WARNING: 2/10 Target722 not recoverable due to insufficient samples.
# WARNING: 3/10 Target723 not recoverable due to insufficient samples.
# WARNING: 4/10 Target724 not recoverable due to insufficient samples.
# Processing 5/10 Target726
# 5/10 Target726 FINISHED with n_TFs: 42
# WARNING: 6/10 Target727 not recoverable due to insufficient samples.
# WARNING: 7/10 Target728 not recoverable due to insufficient samples.
# Processing 8/10 Target729
# 8/10 Target729 FINISHED with n_TFs: 42
# WARNING: 9/10 Target730 not recoverable due to insufficient samples.
# Processing 0/5 Target532
# 0/5 Target532 FINISHED with n_TFs: 25
# Processing 1/5 Target533
# 1/5 Target533 FINISHED with n_TFs: 25
# Processing 2/5 Target534
# 2/5 Target534 FINISHED with n_TFs: 25
# Processing 3/5 Target535
# 3/5 Target535 FINISHED with n_TFs: 25
# Processing 4/5 Target536
# 4/5 Target536 FINISHED with n_TFs: 25
# Processing 0/11 Target3
# 0/11 Target3 FINISHED with n_TFs: 42
# Processing 1/11 Target5
# 1/11 Target5 FINISHED with n_TFs: 42
# Processing 2/11 Target6
# 2/11 Target6 FINISHED with n_TFs: 42
# Processing 3/11 Target8
# 3/11 Target8 FINISHED with n_TFs: 42
# WARNING: 4/11 Target9 not recoverable due to insufficient samples.
# WARNING: 5/11 Target10 not recoverable due to insufficient samples.
# Processing 6/11 Target11
# 6/11 Target11 FINISHED with n_TFs: 42
# Processing 7/11 Target12
# 7/11 Target12 FINISHED with n_TFs: 42
# Processing 8/11 Target13
# 8/11 Target13 FINISHED with n_TFs: 42
# Processing 9/11 Target15
# 9/11 Target15 FINISHED with n_TFs: 42
# WARNING: 10/11 Target17 not recoverable due to insufficient samples.
# Processing 0/6 Target185
# 0/6 Target185 FINISHED with n_TFs: 25
# Processing 1/6 Target187
# 1/6 Target187 FINISHED with n_TFs: 25
# Processing 2/6 Target188
# 2/6 Target188 FINISHED with n_TFs: 25
# Processing 3/6 Target189
# 3/6 Target189 FINISHED with n_TFs: 25
# Processing 4/6 Target190
# 4/6 Target190 FINISHED with n_TFs: 25
# Processing 5/6 Target192
# 5/6 Target192 FINISHED with n_TFs: 25
# Processing 0/10 Target492
# 0/10 Target492 FINISHED with n_TFs: 42
# WARNING: 1/10 Target493 not recoverable due to insufficient samples.
# WARNING: 2/10 Target494 not recoverable due to insufficient samples.
# WARNING: 3/10 Target495 not recoverable due to insufficient samples.
# WARNING: 4/10 Target496 not recoverable due to insufficient samples.
# WARNING: 5/10 Target497 not recoverable due to insufficient samples.
# WARNING: 6/10 Target498 not recoverable due to insufficient samples.
# WARNING: 7/10 Target499 not recoverable due to insufficient samples.
# Processing 8/10 Target500
# 8/10 Target500 FINISHED with n_TFs: 42
# Processing 9/10 Target501
# 9/10 Target501 FINISHED with n_TFs: 42
# WARNING: 0/10 Target731 not recoverable due to insufficient samples.
# WARNING: 1/10 Target732 not recoverable due to insufficient samples.
# WARNING: 2/10 Target733 not recoverable due to insufficient samples.
# WARNING: 3/10 Target734 not recoverable due to insufficient samples.
# WARNING: 4/10 Target735 not recoverable due to insufficient samples.
# WARNING: 5/10 Target736 not recoverable due to insufficient samples.
# WARNING: 6/10 Target737 not recoverable due to insufficient samples.
# WARNING: 7/10 Target738 not recoverable due to insufficient samples.
# Processing 8/10 Target739
# 8/10 Target739 FINISHED with n_TFs: 42
# WARNING: 9/10 Target740 not recoverable due to insufficient samples.
# Processing 0/6 Target201
# 0/6 Target201 FINISHED with n_TFs: 25
# Processing 1/6 Target202
# 1/6 Target202 FINISHED with n_TFs: 25
# Processing 2/6 Target203
# 2/6 Target203 FINISHED with n_TFs: 25
# Processing 3/6 Target204
# 3/6 Target204 FINISHED with n_TFs: 25
# Processing 4/6 Target205
# 4/6 Target205 FINISHED with n_TFs: 25
# Processing 5/6 Target206
# 5/6 Target206 FINISHED with n_TFs: 25
# WARNING: 0/10 Target344 not recoverable due to insufficient samples.
# WARNING: 1/10 Target345 not recoverable due to insufficient samples.
# WARNING: 2/10 Target346 not recoverable due to insufficient samples.
# WARNING: 3/10 Target347 not recoverable due to insufficient samples.
# Processing 4/10 Target348
# 4/10 Target348 FINISHED with n_TFs: 42
# WARNING: 5/10 Target349 not recoverable due to insufficient samples.
# WARNING: 6/10 Target353 not recoverable due to insufficient samples.
# Processing 7/10 Target354
# 7/10 Target354 FINISHED with n_TFs: 42
# Processing 8/10 Target355
# 8/10 Target355 FINISHED with n_TFs: 42
# Processing 9/10 Target357
# 9/10 Target357 FINISHED with n_TFs: 42
# WARNING: 0/10 Target502 not recoverable due to insufficient samples.
# WARNING: 1/10 Target503 not recoverable due to insufficient samples.
# WARNING: 2/10 Target504 not recoverable due to insufficient samples.
# WARNING: 3/10 Target505 not recoverable due to insufficient samples.
# WARNING: 4/10 Target506 not recoverable due to insufficient samples.
# WARNING: 5/10 Target507 not recoverable due to insufficient samples.
# Processing 6/10 Target508
# 6/10 Target508 FINISHED with n_TFs: 42
# WARNING: 7/10 Target509 not recoverable due to insufficient samples.
# Processing 8/10 Target510
# 8/10 Target510 FINISHED with n_TFs: 42
# WARNING: 9/10 Target511 not recoverable due to insufficient samples.
# WARNING: 0/10 Target512 not recoverable due to insufficient samples.
# WARNING: 1/10 Target513 not recoverable due to insufficient samples.
# WARNING: 2/10 Target514 not recoverable due to insufficient samples.
# Processing 3/10 Target515
# 3/10 Target515 FINISHED with n_TFs: 42
# Processing 4/10 Target516
# 4/10 Target516 FINISHED with n_TFs: 42
# WARNING: 5/10 Target517 not recoverable due to insufficient samples.
# WARNING: 6/10 Target518 not recoverable due to insufficient samples.
# WARNING: 7/10 Target519 not recoverable due to insufficient samples.
# WARNING: 8/10 Target521 not recoverable due to insufficient samples.
# WARNING: 9/10 Target522 not recoverable due to insufficient samples.
# Processing 0/5 Target433
# 0/5 Target433 FINISHED with n_TFs: 25
# Processing 1/5 Target435
# 1/5 Target435 FINISHED with n_TFs: 25
# Processing 2/5 Target437
# 2/5 Target437 FINISHED with n_TFs: 25
# Processing 3/5 Target438
# 3/5 Target438 FINISHED with n_TFs: 25
# Processing 4/5 Target439
# 4/5 Target439 FINISHED with n_TFs: 25
# Processing 0/11 Target83
# 0/11 Target83 FINISHED with n_TFs: 42
# Processing 1/11 Target104
# 1/11 Target104 FINISHED with n_TFs: 42
# Processing 2/11 Target106
# 2/11 Target106 FINISHED with n_TFs: 42
# Processing 3/11 Target117
# 3/11 Target117 FINISHED with n_TFs: 42
# Processing 4/11 Target118
# 4/11 Target118 FINISHED with n_TFs: 42
# Processing 5/11 Target119
# 5/11 Target119 FINISHED with n_TFs: 42
# Processing 6/11 Target121
# 6/11 Target121 FINISHED with n_TFs: 42
# Processing 7/11 Target125
# 7/11 Target125 FINISHED with n_TFs: 42
# Processing 8/11 Target127
# 8/11 Target127 FINISHED with n_TFs: 42
# Processing 9/11 Target128
# 9/11 Target128 FINISHED with n_TFs: 42
# Processing 10/11 Target129
# 10/11 Target129 FINISHED with n_TFs: 42
# Processing 0/5 Target707
# 0/5 Target707 FINISHED with n_TFs: 25
# Processing 1/5 Target708
# 1/5 Target708 FINISHED with n_TFs: 25
# Processing 2/5 Target710
# 2/5 Target710 FINISHED with n_TFs: 25
# Processing 3/5 Target711
# 3/5 Target711 FINISHED with n_TFs: 25
# Processing 4/5 Target712
# 4/5 Target712 FINISHED with n_TFs: 25
# Processing 0/11 Target69
# 0/11 Target69 FINISHED with n_TFs: 42
# Processing 1/11 Target72
# 1/11 Target72 FINISHED with n_TFs: 42
# Processing 2/11 Target73
# 2/11 Target73 FINISHED with n_TFs: 42
# Processing 3/11 Target74
# 3/11 Target74 FINISHED with n_TFs: 42
# Processing 4/11 Target75
# 4/11 Target75 FINISHED with n_TFs: 42
# Processing 5/11 Target76
# 5/11 Target76 FINISHED with n_TFs: 42
# Processing 6/11 Target77
# 6/11 Target77 FINISHED with n_TFs: 42
# Processing 7/11 Target78
# 7/11 Target78 FINISHED with n_TFs: 42
# Processing 8/11 Target79
# 8/11 Target79 FINISHED with n_TFs: 42
# Processing 9/11 Target80
# 9/11 Target80 FINISHED with n_TFs: 42
# Processing 10/11 Target82
# 10/11 Target82 FINISHED with n_TFs: 42
# Processing 0/5 Target560
# 0/5 Target560 FINISHED with n_TFs: 25
# Processing 1/5 Target561
# 1/5 Target561 FINISHED with n_TFs: 25
# Processing 2/5 Target562
# 2/5 Target562 FINISHED with n_TFs: 25
# Processing 3/5 Target563
# 3/5 Target563 FINISHED with n_TFs: 25
# Processing 4/5 Target565
# 4/5 Target565 FINISHED with n_TFs: 25
# Processing 0/11 Target142
# 0/11 Target142 FINISHED with n_TFs: 42
# Processing 1/11 Target143
# 1/11 Target143 FINISHED with n_TFs: 42
# Processing 2/11 Target144
# 2/11 Target144 FINISHED with n_TFs: 42
# Processing 3/11 Target145
# 3/11 Target145 FINISHED with n_TFs: 42
# Processing 4/11 Target146
# 4/11 Target146 FINISHED with n_TFs: 42
# Processing 5/11 Target147
# 5/11 Target147 FINISHED with n_TFs: 42
# Processing 6/11 Target148
# 6/11 Target148 FINISHED with n_TFs: 42
# Processing 7/11 Target149
# 7/11 Target149 FINISHED with n_TFs: 42
# Processing 8/11 Target150
# 8/11 Target150 FINISHED with n_TFs: 42
# Processing 9/11 Target151
# 9/11 Target151 FINISHED with n_TFs: 42
# Processing 10/11 Target152
# 10/11 Target152 FINISHED with n_TFs: 42
# Processing 0/5 Target520
# 0/5 Target520 FINISHED with n_TFs: 25
# Processing 1/5 Target522
# 1/5 Target522 FINISHED with n_TFs: 25
# Processing 2/5 Target523
# 2/5 Target523 FINISHED with n_TFs: 25
# Processing 3/5 Target524
# 3/5 Target524 FINISHED with n_TFs: 25
# Processing 4/5 Target525
# 4/5 Target525 FINISHED with n_TFs: 25
# Processing 0/11 Target57
# 0/11 Target57 FINISHED with n_TFs: 42
# Processing 1/11 Target58
# 1/11 Target58 FINISHED with n_TFs: 42
# Processing 2/11 Target59
# 2/11 Target59 FINISHED with n_TFs: 42
# WARNING: 3/11 Target60 not recoverable due to insufficient samples.
# Processing 4/11 Target61
# 4/11 Target61 FINISHED with n_TFs: 42
# Processing 5/11 Target62
# 5/11 Target62 FINISHED with n_TFs: 42
# Processing 6/11 Target64
# 6/11 Target64 FINISHED with n_TFs: 42
# Processing 7/11 Target65
# 7/11 Target65 FINISHED with n_TFs: 42
# Processing 8/11 Target66
# 8/11 Target66 FINISHED with n_TFs: 42
# Processing 9/11 Target67
# 9/11 Target67 FINISHED with n_TFs: 42
# Processing 10/11 Target68
# 10/11 Target68 FINISHED with n_TFs: 42
# Processing 0/5 Target567
# 0/5 Target567 FINISHED with n_TFs: 25
# Processing 1/5 Target574
# 1/5 Target574 FINISHED with n_TFs: 25
# Processing 2/5 Target575
# 2/5 Target575 FINISHED with n_TFs: 25
# Processing 3/5 Target576
# 3/5 Target576 FINISHED with n_TFs: 25
# Processing 4/5 Target577
# 4/5 Target577 FINISHED with n_TFs: 25
# WARNING: 0/11 Target18 not recoverable due to insufficient samples.
# Processing 1/11 Target19
# 1/11 Target19 FINISHED with n_TFs: 42
# Processing 2/11 Target20
# 2/11 Target20 FINISHED with n_TFs: 42
# Processing 3/11 Target21
# 3/11 Target21 FINISHED with n_TFs: 42
# Processing 4/11 Target22
# 4/11 Target22 FINISHED with n_TFs: 42
# Processing 5/11 Target23
# 5/11 Target23 FINISHED with n_TFs: 42
# Processing 6/11 Target24
# 6/11 Target24 FINISHED with n_TFs: 42
# Processing 7/11 Target25
# 7/11 Target25 FINISHED with n_TFs: 42
# Processing 8/11 Target26
# 8/11 Target26 FINISHED with n_TFs: 42
# Processing 9/11 Target27
# 9/11 Target27 FINISHED with n_TFs: 42
# Processing 10/11 Target28
# 10/11 Target28 FINISHED with n_TFs: 42
# Processing 0/5 Target623
# 0/5 Target623 FINISHED with n_TFs: 25
# Processing 1/5 Target625
# 1/5 Target625 FINISHED with n_TFs: 25
# Processing 2/5 Target626
# 2/5 Target626 FINISHED with n_TFs: 25
# Processing 3/5 Target628
# 3/5 Target628 FINISHED with n_TFs: 25
# Processing 4/5 Target629
# 4/5 Target629 FINISHED with n_TFs: 25
# Processing 0/11 C4_TF1
# 0/11 C4_TF1 FINISHED with n_TFs: 41
# Processing 1/11 C4_TF2
# 1/11 C4_TF2 FINISHED with n_TFs: 41
# Processing 2/11 C5_TF1
# 2/11 C5_TF1 FINISHED with n_TFs: 41
# Processing 3/11 C5_TF2
# 3/11 C5_TF2 FINISHED with n_TFs: 41
# Processing 4/11 C6_TF1
# 4/11 C6_TF1 FINISHED with n_TFs: 41
# Processing 5/11 C6_TF2
# 5/11 C6_TF2 FINISHED with n_TFs: 41
# Processing 6/11 C7_TF1
# 6/11 C7_TF1 FINISHED with n_TFs: 41
# Processing 7/11 C7_TF2
# 7/11 C7_TF2 FINISHED with n_TFs: 41
# Processing 8/11 C8_TF1
# 8/11 C8_TF1 FINISHED with n_TFs: 41
# Processing 9/11 C9_TF1
# 9/11 C9_TF1 FINISHED with n_TFs: 41
# Processing 10/11 C9_TF2
# 10/11 C9_TF2 FINISHED with n_TFs: 41
# WARNING: 0/10 Target687 not recoverable due to insufficient samples.
# Processing 1/10 Target688
# 1/10 Target688 FINISHED with n_TFs: 42
# Processing 2/10 Target695
# 2/10 Target695 FINISHED with n_TFs: 42
# WARNING: 3/10 Target696 not recoverable due to insufficient samples.
# WARNING: 4/10 Target697 not recoverable due to insufficient samples.
# WARNING: 5/10 Target698 not recoverable due to insufficient samples.
# WARNING: 6/10 Target699 not recoverable due to insufficient samples.
# WARNING: 7/10 Target700 not recoverable due to insufficient samples.
# Processing 8/10 Target701
# 8/10 Target701 FINISHED with n_TFs: 42
# WARNING: 9/10 Target702 not recoverable due to insufficient samples.
# Processing 0/5 Target537
# 0/5 Target537 FINISHED with n_TFs: 25
# Processing 1/5 Target538
# 1/5 Target538 FINISHED with n_TFs: 25
# Processing 2/5 Target541
# 2/5 Target541 FINISHED with n_TFs: 25
# Processing 3/5 Target542
# 3/5 Target542 FINISHED with n_TFs: 25
# Processing 4/5 Target545
# 4/5 Target545 FINISHED with n_TFs: 25
# Processing 0/11 Target130
# 0/11 Target130 FINISHED with n_TFs: 42
# Processing 1/11 Target131
# 1/11 Target131 FINISHED with n_TFs: 42
# Processing 2/11 Target132
# 2/11 Target132 FINISHED with n_TFs: 42
# Processing 3/11 Target133
# 3/11 Target133 FINISHED with n_TFs: 42
# Processing 4/11 Target134
# 4/11 Target134 FINISHED with n_TFs: 42
# Processing 5/11 Target135
# 5/11 Target135 FINISHED with n_TFs: 42
# Processing 6/11 Target137
# 6/11 Target137 FINISHED with n_TFs: 42
# Processing 7/11 Target138
# 7/11 Target138 FINISHED with n_TFs: 42
# Processing 8/11 Target139
# 8/11 Target139 FINISHED with n_TFs: 42
# Processing 9/11 Target140
# 9/11 Target140 FINISHED with n_TFs: 42
# Processing 10/11 Target141
# 10/11 Target141 FINISHED with n_TFs: 42
# Processing 0/6 Target282
# 0/6 Target282 FINISHED with n_TFs: 25
# Processing 1/6 Target283
# 1/6 Target283 FINISHED with n_TFs: 25
# Processing 2/6 Target284
# 2/6 Target284 FINISHED with n_TFs: 25
# Processing 3/6 Target285
# 3/6 Target285 FINISHED with n_TFs: 25
# Processing 4/6 Target286
# 4/6 Target286 FINISHED with n_TFs: 25
# Processing 5/6 Target287
# 5/6 Target287 FINISHED with n_TFs: 25
# Processing 0/10 Target391
# 0/10 Target391 FINISHED with n_TFs: 42
# Processing 1/10 Target394
# 1/10 Target394 FINISHED with n_TFs: 42
# Processing 2/10 Target399
# 2/10 Target399 FINISHED with n_TFs: 42
# Processing 3/10 Target405
# 3/10 Target405 FINISHED with n_TFs: 42
# Processing 4/10 Target408
# 4/10 Target408 FINISHED with n_TFs: 42
# WARNING: 5/10 Target409 not recoverable due to insufficient samples.
# WARNING: 6/10 Target410 not recoverable due to insufficient samples.
# WARNING: 7/10 Target411 not recoverable due to insufficient samples.
# WARNING: 8/10 Target412 not recoverable due to insufficient samples.
# WARNING: 9/10 Target413 not recoverable due to insufficient samples.
# Processing 0/5 Target546
# 0/5 Target546 FINISHED with n_TFs: 25
# Processing 1/5 Target547
# 1/5 Target547 FINISHED with n_TFs: 25
# Processing 2/5 Target548
# 2/5 Target548 FINISHED with n_TFs: 25
# Processing 3/5 Target549
# 3/5 Target549 FINISHED with n_TFs: 25
# Processing 4/5 Target550
# 4/5 Target550 FINISHED with n_TFs: 25
# Processing 0/11 Burn4_TF1
# 0/11 Burn4_TF1 FINISHED with n_TFs: 41
# Processing 1/11 A5_TF2
# 1/11 A5_TF2 FINISHED with n_TFs: 41
# Processing 2/11 B1_TF1
# 2/11 B1_TF1 FINISHED with n_TFs: 41
# Processing 3/11 B1_TF2
# 3/11 B1_TF2 FINISHED with n_TFs: 41
# Processing 4/11 B2_TF1
# 4/11 B2_TF1 FINISHED with n_TFs: 41
# Processing 5/11 B3_TF1
# 5/11 B3_TF1 FINISHED with n_TFs: 41
# Processing 6/11 B4_TF1
# 6/11 B4_TF1 FINISHED with n_TFs: 41
# Processing 7/11 B4_TF2
# 7/11 B4_TF2 FINISHED with n_TFs: 41
# Processing 8/11 C1_TF1
# 8/11 C1_TF1 FINISHED with n_TFs: 41
# Processing 9/11 C2_TF1
# 9/11 C2_TF1 FINISHED with n_TFs: 41
# Processing 10/11 C3_TF1
# 10/11 C3_TF1 FINISHED with n_TFs: 41
# Processing 0/5 Target554
# 0/5 Target554 FINISHED with n_TFs: 25
# Processing 1/5 Target556
# 1/5 Target556 FINISHED with n_TFs: 25
# Processing 2/5 Target557
# 2/5 Target557 FINISHED with n_TFs: 25
# Processing 3/5 Target558
# 3/5 Target558 FINISHED with n_TFs: 25
# Processing 4/5 Target559
# 4/5 Target559 FINISHED with n_TFs: 25
# Processing 0/11 Target45
# 0/11 Target45 FINISHED with n_TFs: 42
# Processing 1/11 Target46
# 1/11 Target46 FINISHED with n_TFs: 42
# Processing 2/11 Target47
# 2/11 Target47 FINISHED with n_TFs: 42
# Processing 3/11 Target48
# 3/11 Target48 FINISHED with n_TFs: 42
# Processing 4/11 Target50
# 4/11 Target50 FINISHED with n_TFs: 42
# Processing 5/11 Target51
# 5/11 Target51 FINISHED with n_TFs: 42
# Processing 6/11 Target52
# 6/11 Target52 FINISHED with n_TFs: 42
# Processing 7/11 Target53
# 7/11 Target53 FINISHED with n_TFs: 42
# Processing 8/11 Target54
# 8/11 Target54 FINISHED with n_TFs: 42
# Processing 9/11 Target55
# 9/11 Target55 FINISHED with n_TFs: 42
# Processing 10/11 Target56
# 10/11 Target56 FINISHED with n_TFs: 42
# Processing 0/5 Target777
# 0/5 Target777 FINISHED with n_TFs: 25
# Processing 1/5 Target782
# 1/5 Target782 FINISHED with n_TFs: 25
# Processing 2/5 Target792
# 2/5 Target792 FINISHED with n_TFs: 25
# Processing 3/5 Target796
# 3/5 Target796 FINISHED with n_TFs: 25
# Processing 4/5 Target798
# 4/5 Target798 FINISHED with n_TFs: 25
# Processing 0/11 Target29
# 0/11 Target29 FINISHED with n_TFs: 42
# Processing 1/11 Target32
# 1/11 Target32 FINISHED with n_TFs: 42
# Processing 2/11 Target34
# 2/11 Target34 FINISHED with n_TFs: 42
# Processing 3/11 Target35
# 3/11 Target35 FINISHED with n_TFs: 42
# Processing 4/11 Target36
# 4/11 Target36 FINISHED with n_TFs: 42
# Processing 5/11 Target37
# 5/11 Target37 FINISHED with n_TFs: 42
# Processing 6/11 Target39
# 6/11 Target39 FINISHED with n_TFs: 42
# Processing 7/11 Target40
# 7/11 Target40 FINISHED with n_TFs: 42
# Processing 8/11 Target41
# 8/11 Target41 FINISHED with n_TFs: 42
# Processing 9/11 Target42
# 9/11 Target42 FINISHED with n_TFs: 42
# Processing 10/11 Target44
# 10/11 Target44 FINISHED with n_TFs: 42
# Processing 0/6 Target337
# 0/6 Target337 FINISHED with n_TFs: 25
# Processing 1/6 Target338
# 1/6 Target338 FINISHED with n_TFs: 25
# Processing 2/6 Target339
# 2/6 Target339 FINISHED with n_TFs: 25
# Processing 3/6 Target340
# 3/6 Target340 FINISHED with n_TFs: 25
# Processing 4/6 Target341
# 4/6 Target341 FINISHED with n_TFs: 25
# Processing 5/6 Target342
# 5/6 Target342 FINISHED with n_TFs: 25
# WARNING: 0/10 Target302 not recoverable due to insufficient samples.
# WARNING: 1/10 Target303 not recoverable due to insufficient samples.
# Processing 2/10 Target304
# 2/10 Target304 FINISHED with n_TFs: 42
# Processing 3/10 Target306
# 3/10 Target306 FINISHED with n_TFs: 42
# Processing 4/10 Target308
# 4/10 Target308 FINISHED with n_TFs: 42
# Processing 5/10 Target313
# 5/10 Target313 FINISHED with n_TFs: 42
# Processing 6/10 Target318
# 6/10 Target318 FINISHED with n_TFs: 42
# Processing 7/10 Target319
# 7/10 Target319 FINISHED with n_TFs: 42
# Processing 8/10 Target320
# 8/10 Target320 FINISHED with n_TFs: 42
# Processing 9/10 Target321
# 9/10 Target321 FINISHED with n_TFs: 42
#     finished (0:19:07) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# WARNING: 0/10 Target741 not recoverable due to insufficient samples.
# WARNING: 1/10 Target742 not recoverable due to insufficient samples.
# WARNING: 2/10 Target743 not recoverable due to insufficient samples.
# Processing 3/10 Target744
# 3/10 Target744 FINISHED with n_TFs: 42
# WARNING: 4/10 Target745 not recoverable due to insufficient samples.
# Processing 5/10 Target746
# 5/10 Target746 FINISHED with n_TFs: 42
# Processing 6/10 Target747
# 6/10 Target747 FINISHED with n_TFs: 42
# Processing 7/10 Target748
# 7/10 Target748 FINISHED with n_TFs: 42
# WARNING: 8/10 Target749 not recoverable due to insufficient samples.
# WARNING: 9/10 Target750 not recoverable due to insufficient samples.
# Run 2, dataset 24.
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'M_total', moments of total abundances (adata.layers)
# Processing 0/10 Target523
# 0/10 Target523 FINISHED with n_TFs: 42
# WARNING: 1/10 Target524 not recoverable due to insufficient samples.
# WARNING: 2/10 Target525 not recoverable due to insufficient samples.
# WARNING: 3/10 Target526 not recoverable due to insufficient samples.
# WARNING: 4/10 Target527 not recoverable due to insufficient samples.
# Processing 5/10 Target528
# 5/10 Target528 FINISHED with n_TFs: 42
# Processing 6/10 Target529
# 6/10 Target529 FINISHED with n_TFs: 42
# Processing 7/10 Target530
# 7/10 Target530 FINISHED with n_TFs: 42
# Processing 8/10 Target531
# 8/10 Target531 FINISHED with n_TFs: 42
# WARNING: 9/10 Target533 not recoverable due to insufficient samples.
# recovering dynamics (using 64/128 cores)
#   0%|          | 0/726 [00:00<?, ?gene/s]
# WARNING: 0/10 Target534 not recoverable due to insufficient samples.
# WARNING: 1/10 Target535 not recoverable due to insufficient samples.
# WARNING: 2/10 Target536 not recoverable due to insufficient samples.
# WARNING: 3/10 Target538 not recoverable due to insufficient samples.
# WARNING: 4/10 Target539 not recoverable due to insufficient samples.
# Processing 5/10 Target540
# 5/10 Target540 FINISHED with n_TFs: 42
# Processing 6/10 Target541
# 6/10 Target541 FINISHED with n_TFs: 42
# Processing 7/10 Target542
# 7/10 Target542 FINISHED with n_TFs: 42
# Processing 8/10 Target545
# 8/10 Target545 FINISHED with n_TFs: 42
# Processing 9/10 Target548
# 9/10 Target548 FINISHED with n_TFs: 42
# Processing 0/6 Target194
# 0/6 Target194 FINISHED with n_TFs: 25
# Processing 1/6 Target195
# 1/6 Target195 FINISHED with n_TFs: 25
# Processing 2/6 Target196
# 2/6 Target196 FINISHED with n_TFs: 25
# Processing 3/6 Target197
# 3/6 Target197 FINISHED with n_TFs: 25
# Processing 4/6 Target198
# 4/6 Target198 FINISHED with n_TFs: 25
# Processing 5/6 Target200
# 5/6 Target200 FINISHED with n_TFs: 25
# Processing 0/11 Target248
# 0/11 Target248 FINISHED with n_TFs: 42
# Processing 1/11 Target249
# 1/11 Target249 FINISHED with n_TFs: 42
# Processing 2/11 Target250
# 2/11 Target250 FINISHED with n_TFs: 42
# Processing 3/11 Target251
# 3/11 Target251 FINISHED with n_TFs: 42
# Processing 4/11 Target252
# 4/11 Target252 FINISHED with n_TFs: 42
# Processing 5/11 Target253
# 5/11 Target253 FINISHED with n_TFs: 42
# Processing 6/11 Target254
# 6/11 Target254 FINISHED with n_TFs: 42
# Processing 7/11 Target255
# 7/11 Target255 FINISHED with n_TFs: 42
# Processing 8/11 Target256
# 8/11 Target256 FINISHED with n_TFs: 42
# Processing 9/11 Target257
# 9/11 Target257 FINISHED with n_TFs: 42
# Processing 10/11 Target258
# 10/11 Target258 FINISHED with n_TFs: 42
# Processing 0/6 Target383
# 0/6 Target383 FINISHED with n_TFs: 25
# Processing 1/6 Target385
# 1/6 Target385 FINISHED with n_TFs: 25
# Processing 2/6 Target388
# 2/6 Target388 FINISHED with n_TFs: 25
# Processing 3/6 Target389
# 3/6 Target389 FINISHED with n_TFs: 25
# Processing 4/6 Target395
# 4/6 Target395 FINISHED with n_TFs: 25
# Processing 5/6 Target400
# 5/6 Target400 FINISHED with n_TFs: 25
# Processing 0/10 Target477
# 0/10 Target477 FINISHED with n_TFs: 42
# Processing 1/10 Target479
# 1/10 Target479 FINISHED with n_TFs: 42
# Processing 2/10 Target480
# 2/10 Target480 FINISHED with n_TFs: 42
# Processing 3/10 Target481
# 3/10 Target481 FINISHED with n_TFs: 42
# Processing 4/10 Target484
# 4/10 Target484 FINISHED with n_TFs: 42
# Processing 5/10 Target485
# 5/10 Target485 FINISHED with n_TFs: 42
# Processing 6/10 Target486
# 6/10 Target486 FINISHED with n_TFs: 42
# Processing 7/10 Target488
# 7/10 Target488 FINISHED with n_TFs: 42
# Processing 8/10 Target489
# 8/10 Target489 FINISHED with n_TFs: 42
# Processing 9/10 Target491
# 9/10 Target491 FINISHED with n_TFs: 42
# Processing 0/12 Target278
# 0/12 Target278 FINISHED with n_TFs: 54
# WARNING: 1/12 Target279 not recoverable due to insufficient samples.
# Processing 2/12 Target280
# 2/12 Target280 FINISHED with n_TFs: 54
# WARNING: 3/12 Target281 not recoverable due to insufficient samples.
# Processing 4/12 Target282
# 4/12 Target282 FINISHED with n_TFs: 54
# WARNING: 5/12 Target283 not recoverable due to insufficient samples.
# WARNING: 6/12 Target284 not recoverable due to insufficient samples.
# WARNING: 7/12 Target285 not recoverable due to insufficient samples.
# WARNING: 8/12 Target286 not recoverable due to insufficient samples.
# WARNING: 9/12 Target287 not recoverable due to insufficient samples.
# WARNING: 10/12 Target288 not recoverable due to insufficient samples.
# WARNING: 11/12 Target289 not recoverable due to insufficient samples.
# Processing 0/10 Target762
# 0/10 Target762 FINISHED with n_TFs: 42
# Processing 1/10 Target763
# 1/10 Target763 FINISHED with n_TFs: 42
# Processing 2/10 Target764
# 2/10 Target764 FINISHED with n_TFs: 42
# Processing 3/10 Target765
# 3/10 Target765 FINISHED with n_TFs: 42
# Processing 4/10 Target766
# 4/10 Target766 FINISHED with n_TFs: 42
# Processing 5/10 Target767
# 5/10 Target767 FINISHED with n_TFs: 42
# Processing 6/10 Target768
# 6/10 Target768 FINISHED with n_TFs: 42
# Processing 7/10 Target769
# 7/10 Target769 FINISHED with n_TFs: 42
# Processing 8/10 Target770
# 8/10 Target770 FINISHED with n_TFs: 42
# Processing 9/10 Target771
# 9/10 Target771 FINISHED with n_TFs: 42
# WARNING: 0/11 Target444 not recoverable due to insufficient samples.
# Processing 1/11 Target445
# 1/11 Target445 FINISHED with n_TFs: 54
# WARNING: 2/11 Target446 not recoverable due to insufficient samples.
# Processing 3/11 Target447
# 3/11 Target447 FINISHED with n_TFs: 54
# WARNING: 4/11 Target448 not recoverable due to insufficient samples.
# WARNING: 5/11 Target449 not recoverable due to insufficient samples.
# WARNING: 6/11 Target450 not recoverable due to insufficient samples.
# WARNING: 7/11 Target451 not recoverable due to insufficient samples.
# Processing 8/11 Target452
# 8/11 Target452 FINISHED with n_TFs: 54
# WARNING: 9/11 Target453 not recoverable due to insufficient samples.
# WARNING: 10/11 Target454 not recoverable due to insufficient samples.
# Processing 0/10 Target772
# 0/10 Target772 FINISHED with n_TFs: 42
# Processing 1/10 Target773
# 1/10 Target773 FINISHED with n_TFs: 42
# Processing 2/10 Target774
# 2/10 Target774 FINISHED with n_TFs: 42
# WARNING: 3/10 Target775 not recoverable due to insufficient samples.
# WARNING: 4/10 Target776 not recoverable due to insufficient samples.
# Processing 5/10 Target777
# 5/10 Target777 FINISHED with n_TFs: 42
# Processing 6/10 Target778
# 6/10 Target778 FINISHED with n_TFs: 42
# WARNING: 7/10 Target780 not recoverable due to insufficient samples.
# Processing 8/10 Target781
# 8/10 Target781 FINISHED with n_TFs: 42
# WARNING: 9/10 Target782 not recoverable due to insufficient samples.
# WARNING: 0/12 D2_TF1 not recoverable due to insufficient samples.
# Processing 1/12 D3_TF1
# 1/12 D3_TF1 FINISHED with n_TFs: 53
# Processing 2/12 D3_TF2
# 2/12 D3_TF2 FINISHED with n_TFs: 53
# Processing 3/12 D3_TF3
# 3/12 D3_TF3 FINISHED with n_TFs: 53
# Processing 4/12 D3_TF4
# 4/12 D3_TF4 FINISHED with n_TFs: 53
# WARNING: 5/12 D4_TF1 not recoverable due to insufficient samples.
# Processing 6/12 Target1
# 6/12 Target1 FINISHED with n_TFs: 54
# Processing 7/12 Target2
# 7/12 Target2 FINISHED with n_TFs: 54
# WARNING: 8/12 Target3 not recoverable due to insufficient samples.
# Processing 9/12 Target4
# 9/12 Target4 FINISHED with n_TFs: 54
# WARNING: 10/12 Target5 not recoverable due to insufficient samples.
# Processing 11/12 Target6
# 11/12 Target6 FINISHED with n_TFs: 54
# Processing 0/10 Target676
# 0/10 Target676 FINISHED with n_TFs: 42
# Processing 1/10 Target677
# 1/10 Target677 FINISHED with n_TFs: 42
# Processing 2/10 Target678
# 2/10 Target678 FINISHED with n_TFs: 42
# Processing 3/10 Target679
# 3/10 Target679 FINISHED with n_TFs: 42
# WARNING: 4/10 Target681 not recoverable due to insufficient samples.
# WARNING: 5/10 Target682 not recoverable due to insufficient samples.
# WARNING: 6/10 Target683 not recoverable due to insufficient samples.
# Processing 7/10 Target684
# 7/10 Target684 FINISHED with n_TFs: 42
# WARNING: 8/10 Target685 not recoverable due to insufficient samples.
# Processing 9/10 Target686
# 9/10 Target686 FINISHED with n_TFs: 42
# Processing 0/12 B5_TF2
# 0/12 B5_TF2 FINISHED with n_TFs: 53
# Processing 1/12 B5_TF3
# 1/12 B5_TF3 FINISHED with n_TFs: 53
# Processing 2/12 B5_TF4
# 2/12 B5_TF4 FINISHED with n_TFs: 53
# Processing 3/12 B5_TF5
# 3/12 B5_TF5 FINISHED with n_TFs: 53
# Processing 4/12 C1_TF1
# 4/12 C1_TF1 FINISHED with n_TFs: 53
# Processing 5/12 C1_TF2
# 5/12 C1_TF2 FINISHED with n_TFs: 53
# Processing 6/12 C1_TF3
# 6/12 C1_TF3 FINISHED with n_TFs: 53
# Processing 7/12 C1_TF4
# 7/12 C1_TF4 FINISHED with n_TFs: 53
# Processing 8/12 C2_TF1
# 8/12 C2_TF1 FINISHED with n_TFs: 53
# WARNING: 9/12 C3_TF1 not recoverable due to insufficient samples.
# WARNING: 10/12 C3_TF2 not recoverable due to insufficient samples.
# WARNING: 11/12 C3_TF3 not recoverable due to insufficient samples.
# Processing 0/5 Target610
# 0/5 Target610 FINISHED with n_TFs: 25
# Processing 1/5 Target611
# 1/5 Target611 FINISHED with n_TFs: 25
# Processing 2/5 Target612
# 2/5 Target612 FINISHED with n_TFs: 25
# Processing 3/5 Target613
# 3/5 Target613 FINISHED with n_TFs: 25
# Processing 4/5 Target614
# 4/5 Target614 FINISHED with n_TFs: 25
# Processing 0/11 Target236
# 0/11 Target236 FINISHED with n_TFs: 42
# Processing 1/11 Target237
# 1/11 Target237 FINISHED with n_TFs: 42
# Processing 2/11 Target238
# 2/11 Target238 FINISHED with n_TFs: 42
# Processing 3/11 Target239
# 3/11 Target239 FINISHED with n_TFs: 42
# Processing 4/11 Target240
# 4/11 Target240 FINISHED with n_TFs: 42
# Processing 5/11 Target241
# 5/11 Target241 FINISHED with n_TFs: 42
# Processing 6/11 Target242
# 6/11 Target242 FINISHED with n_TFs: 42
# Processing 7/11 Target244
# 7/11 Target244 FINISHED with n_TFs: 42
# Processing 8/11 Target245
# 8/11 Target245 FINISHED with n_TFs: 42
# Processing 9/11 Target246
# 9/11 Target246 FINISHED with n_TFs: 42
# Processing 10/11 Target247
# 10/11 Target247 FINISHED with n_TFs: 42
# Processing 0/12 Target7
# 0/12 Target7 FINISHED with n_TFs: 54
# Processing 1/12 Target8
# 1/12 Target8 FINISHED with n_TFs: 54
# WARNING: 2/12 Target9 not recoverable due to insufficient samples.
# WARNING: 3/12 Target10 not recoverable due to insufficient samples.
# Processing 4/12 Target12
# 4/12 Target12 FINISHED with n_TFs: 54
# Processing 5/12 Target13
# 5/12 Target13 FINISHED with n_TFs: 54
# Processing 6/12 Target15
# 6/12 Target15 FINISHED with n_TFs: 54
# Processing 7/12 Target17
# 7/12 Target17 FINISHED with n_TFs: 54
# Processing 8/12 Target19
# 8/12 Target19 FINISHED with n_TFs: 54
# Processing 9/12 Target20
# 9/12 Target20 FINISHED with n_TFs: 54
# Processing 10/12 Target21
# 10/12 Target21 FINISHED with n_TFs: 54
# WARNING: 11/12 Target23 not recoverable due to insufficient samples.
# Processing 0/10 Target655
# 0/10 Target655 FINISHED with n_TFs: 42
# Processing 1/10 Target656
# 1/10 Target656 FINISHED with n_TFs: 42
# Processing 2/10 Target657
# 2/10 Target657 FINISHED with n_TFs: 42
# Processing 3/10 Target658
# 3/10 Target658 FINISHED with n_TFs: 42
# Processing 4/10 Target659
# 4/10 Target659 FINISHED with n_TFs: 42
# Processing 5/10 Target660
# 5/10 Target660 FINISHED with n_TFs: 42
# Processing 6/10 Target661
# 6/10 Target661 FINISHED with n_TFs: 42
# Processing 7/10 Target663
# 7/10 Target663 FINISHED with n_TFs: 42
# Processing 8/10 Target664
# 8/10 Target664 FINISHED with n_TFs: 42
# Processing 9/10 Target665
# 9/10 Target665 FINISHED with n_TFs: 42
# WARNING: 0/11 Target290 not recoverable due to insufficient samples.
# Processing 1/11 Target291
# 1/11 Target291 FINISHED with n_TFs: 54
# WARNING: 2/11 Target292 not recoverable due to insufficient samples.
# Processing 3/11 Target293
# 3/11 Target293 FINISHED with n_TFs: 54
# WARNING: 4/11 Target294 not recoverable due to insufficient samples.
# WARNING: 5/11 Target295 not recoverable due to insufficient samples.
# WARNING: 6/11 Target296 not recoverable due to insufficient samples.
# Processing 7/11 Target297
# 7/11 Target297 FINISHED with n_TFs: 54
# Processing 8/11 Target298
# 8/11 Target298 FINISHED with n_TFs: 54
# WARNING: 9/11 Target299 not recoverable due to insufficient samples.
# Processing 10/11 Target300
# 10/11 Target300 FINISHED with n_TFs: 54
# Processing 0/6 Target402
# 0/6 Target402 FINISHED with n_TFs: 25
# Processing 1/6 Target403
# 1/6 Target403 FINISHED with n_TFs: 25
# Processing 2/6 Target404
# 2/6 Target404 FINISHED with n_TFs: 25
# Processing 3/6 Target406
# 3/6 Target406 FINISHED with n_TFs: 25
# Processing 4/6 Target407
# 4/6 Target407 FINISHED with n_TFs: 25
# Processing 5/6 Target408
# 5/6 Target408 FINISHED with n_TFs: 25
# Processing 0/10 Target358
# 0/10 Target358 FINISHED with n_TFs: 42
# Processing 1/10 Target359
# 1/10 Target359 FINISHED with n_TFs: 42
# Processing 2/10 Target360
# 2/10 Target360 FINISHED with n_TFs: 42
# Processing 3/10 Target361
# 3/10 Target361 FINISHED with n_TFs: 42
# Processing 4/10 Target362
# 4/10 Target362 FINISHED with n_TFs: 42
# Processing 5/10 Target363
# 5/10 Target363 FINISHED with n_TFs: 42
# Processing 6/10 Target364
# 6/10 Target364 FINISHED with n_TFs: 42
# Processing 7/10 Target365
# 7/10 Target365 FINISHED with n_TFs: 42
# Processing 8/10 Target366
# 8/10 Target366 FINISHED with n_TFs: 42
# Processing 9/10 Target367
# 9/10 Target367 FINISHED with n_TFs: 42
# Processing 0/12 Target237
# 0/12 Target237 FINISHED with n_TFs: 54
# WARNING: 1/12 Target238 not recoverable due to insufficient samples.
# WARNING: 2/12 Target239 not recoverable due to insufficient samples.
# Processing 3/12 Target240
# 3/12 Target240 FINISHED with n_TFs: 54
# Processing 4/12 Target241
# 4/12 Target241 FINISHED with n_TFs: 54
# Processing 5/12 Target242
# 5/12 Target242 FINISHED with n_TFs: 54
# Processing 6/12 Target248
# 6/12 Target248 FINISHED with n_TFs: 54
# WARNING: 7/12 Target256 not recoverable due to insufficient samples.
# Processing 8/12 Target257
# 8/12 Target257 FINISHED with n_TFs: 54
# WARNING: 9/12 Target258 not recoverable due to insufficient samples.
# WARNING: 10/12 Target259 not recoverable due to insufficient samples.
# WARNING: 11/12 Target260 not recoverable due to insufficient samples.
# Processing 0/5 Target526
# 0/5 Target526 FINISHED with n_TFs: 25
# Processing 1/5 Target527
# 1/5 Target527 FINISHED with n_TFs: 25
# Processing 2/5 Target528
# 2/5 Target528 FINISHED with n_TFs: 25
# Processing 3/5 Target530
# 3/5 Target530 FINISHED with n_TFs: 25
# Processing 4/5 Target531
# 4/5 Target531 FINISHED with n_TFs: 25
# Processing 0/11 Target259
# 0/11 Target259 FINISHED with n_TFs: 42
# Processing 1/11 Target260
# 1/11 Target260 FINISHED with n_TFs: 42
# Processing 2/11 Target261
# 2/11 Target261 FINISHED with n_TFs: 42
# Processing 3/11 Target262
# 3/11 Target262 FINISHED with n_TFs: 42
# Processing 4/11 Target263
# 4/11 Target263 FINISHED with n_TFs: 42
# Processing 5/11 Target264
# 5/11 Target264 FINISHED with n_TFs: 42
# Processing 6/11 Target265
# 6/11 Target265 FINISHED with n_TFs: 42
# Processing 7/11 Target266
# 7/11 Target266 FINISHED with n_TFs: 42
# Processing 8/11 Target267
# 8/11 Target267 FINISHED with n_TFs: 42
# Processing 9/11 Target268
# 9/11 Target268 FINISHED with n_TFs: 42
# Processing 10/11 Target269
# 10/11 Target269 FINISHED with n_TFs: 42
# Processing 0/12 Target148
# 0/12 Target148 FINISHED with n_TFs: 54
# Processing 1/12 Target150
# 1/12 Target150 FINISHED with n_TFs: 54
# WARNING: 2/12 Target151 not recoverable due to insufficient samples.
# Processing 3/12 Target152
# 3/12 Target152 FINISHED with n_TFs: 54
# Processing 4/12 Target153
# 4/12 Target153 FINISHED with n_TFs: 54
# Processing 5/12 Target154
# 5/12 Target154 FINISHED with n_TFs: 54
# WARNING: 6/12 Target155 not recoverable due to insufficient samples.
# WARNING: 7/12 Target156 not recoverable due to insufficient samples.
# Processing 8/12 Target157
# 8/12 Target157 FINISHED with n_TFs: 54
# WARNING: 9/12 Target158 not recoverable due to insufficient samples.
# WARNING: 10/12 Target159 not recoverable due to insufficient samples.
# ...
# Processing 0/4 B5_TF2
# 0/4 B5_TF2 FINISHED with n_TFs: 18
# Processing 1/4 B6_TF1
# 1/4 B6_TF1 FINISHED with n_TFs: 18
# Processing 2/4 C1_TF1
# 2/4 C1_TF1 FINISHED with n_TFs: 18
# Processing 3/4 C2_TF1
# 3/4 C2_TF1 FINISHED with n_TFs: 18
# Processing 0/8 C13_TF1
# 0/8 C13_TF1 FINISHED with n_TFs: 36
# Processing 1/8 C14_TF1
# 1/8 C14_TF1 FINISHED with n_TFs: 36
# Processing 2/8 C14_TF2
# 2/8 C14_TF2 FINISHED with n_TFs: 36
# Processing 3/8 D1_TF1
# 3/8 D1_TF1 FINISHED with n_TFs: 36
# Processing 4/8 D2_TF1
# 4/8 D2_TF1 FINISHED with n_TFs: 36
# Processing 5/8 D4_TF1
# 5/8 D4_TF1 FINISHED with n_TFs: 36
# Processing 6/8 E1_TF1
# 6/8 E1_TF1 FINISHED with n_TFs: 36
# Processing 7/8 E2_TF1
# 7/8 E2_TF1 FINISHED with n_TFs: 36
# Processing 0/9 Target492
# 0/9 Target492 FINISHED with n_TFs: 49
# Processing 1/9 Target493
# 1/9 Target493 FINISHED with n_TFs: 49
# Processing 2/9 Target494
# 2/9 Target494 FINISHED with n_TFs: 49
# Processing 3/9 Target495
# 3/9 Target495 FINISHED with n_TFs: 49
# Processing 4/9 Target496
# 4/9 Target496 FINISHED with n_TFs: 49
# Processing 5/9 Target497
# 5/9 Target497 FINISHED with n_TFs: 49
# Processing 6/9 Target500
# 6/9 Target500 FINISHED with n_TFs: 49
# Processing 7/9 Target501
# 7/9 Target501 FINISHED with n_TFs: 49
# Processing 8/9 Target502
# 8/9 Target502 FINISHED with n_TFs: 49
# Processing 0/5 Target387
# 0/5 Target387 FINISHED with n_TFs: 29
# Processing 1/5 Target388
# 1/5 Target388 FINISHED with n_TFs: 29
# Processing 2/5 Target389
# 2/5 Target389 FINISHED with n_TFs: 29
# Processing 3/5 Target390
# 3/5 Target390 FINISHED with n_TFs: 29
# Processing 4/5 Target391
# 4/5 Target391 FINISHED with n_TFs: 29
# Processing 0/8 Target140
# 0/8 Target140 FINISHED with n_TFs: 37
# WARNING: 1/8 Target141 not recoverable due to insufficient samples.
# Processing 2/8 Target142
# 2/8 Target142 FINISHED with n_TFs: 37
# Processing 3/8 Target143
# 3/8 Target143 FINISHED with n_TFs: 37
# Processing 4/8 Target144
# 4/8 Target144 FINISHED with n_TFs: 37
# WARNING: 5/8 Target145 not recoverable due to insufficient samples.
# Processing 6/8 Target146
# 6/8 Target146 FINISHED with n_TFs: 37
# WARNING: 7/8 Target147 not recoverable due to insufficient samples.
# Processing 0/4 Burn5_TF1
# 0/4 Burn5_TF1 FINISHED with n_TFs: 18
# Processing 1/4 A4_TF3
# 1/4 A4_TF3 FINISHED with n_TFs: 18
# Processing 2/4 A5_TF1
# 2/4 A5_TF1 FINISHED with n_TFs: 18
# Processing 3/4 B1_TF1
# 3/4 B1_TF1 FINISHED with n_TFs: 18
# Processing 0/8 E3_TF1
# 0/8 E3_TF1 FINISHED with n_TFs: 36
# Processing 1/8 E3_TF2
# 1/8 E3_TF2 FINISHED with n_TFs: 36
# Processing 2/8 E4_TF1
# 2/8 E4_TF1 FINISHED with n_TFs: 36
# Processing 3/8 E5_TF1
# 3/8 E5_TF1 FINISHED with n_TFs: 36
# Processing 4/8 E6_TF1
# 4/8 E6_TF1 FINISHED with n_TFs: 36
# Processing 5/8 Target2
# 5/8 Target2 FINISHED with n_TFs: 37
# Processing 6/8 Target3
# 6/8 Target3 FINISHED with n_TFs: 37
# Processing 7/8 Target5
# 7/8 Target5 FINISHED with n_TFs: 37
# WARNING: 0/7 Target684 not recoverable due to insufficient samples.
# WARNING: 1/7 Target685 not recoverable due to insufficient samples.
# Processing 2/7 Target686
# 2/7 Target686 FINISHED with n_TFs: 37
# Processing 3/7 Target687
# 3/7 Target687 FINISHED with n_TFs: 37
# Processing 4/7 Target688
# 4/7 Target688 FINISHED with n_TFs: 37
# Processing 5/7 Target689
# 5/7 Target689 FINISHED with n_TFs: 37
# Processing 6/7 Target690
# 6/7 Target690 FINISHED with n_TFs: 37
# WARNING: 0/3 Target258 not recoverable due to insufficient samples.
# Processing 1/3 Target259
# 1/3 Target259 FINISHED with n_TFs: 19
# Processing 2/3 Target261
# 2/3 Target261 FINISHED with n_TFs: 19
# Processing 0/8 Target20
# 0/8 Target20 FINISHED with n_TFs: 37
# Processing 1/8 Target21
# 1/8 Target21 FINISHED with n_TFs: 37
# Processing 2/8 Target22
# 2/8 Target22 FINISHED with n_TFs: 37
# Processing 3/8 Target23
# 3/8 Target23 FINISHED with n_TFs: 37
# Processing 4/8 Target24
# 4/8 Target24 FINISHED with n_TFs: 37
# Processing 5/8 Target25
# 5/8 Target25 FINISHED with n_TFs: 37
# Processing 6/8 Target26
# 6/8 Target26 FINISHED with n_TFs: 37
# Processing 7/8 Target27
# 7/8 Target27 FINISHED with n_TFs: 37
# Processing 0/7 Target764
# 0/7 Target764 FINISHED with n_TFs: 38
# Processing 1/7 Target765
# 1/7 Target765 FINISHED with n_TFs: 38
# Processing 2/7 Target766
# 2/7 Target766 FINISHED with n_TFs: 38
# Processing 3/7 Target767
# 3/7 Target767 FINISHED with n_TFs: 38
# Processing 4/7 Target768
# 4/7 Target768 FINISHED with n_TFs: 38
# Processing 5/7 Target769
# 5/7 Target769 FINISHED with n_TFs: 38
# Processing 6/7 Target770
# 6/7 Target770 FINISHED with n_TFs: 38
# Processing 0/7 Target543
# 0/7 Target543 FINISHED with n_TFs: 41
# Processing 1/7 Target544
# 1/7 Target544 FINISHED with n_TFs: 41
# Processing 2/7 Target545
# 2/7 Target545 FINISHED with n_TFs: 41
# Processing 3/7 Target546
# 3/7 Target546 FINISHED with n_TFs: 41
# Processing 4/7 Target547
# 4/7 Target547 FINISHED with n_TFs: 41
# Processing 5/7 Target548
# 5/7 Target548 FINISHED with n_TFs: 41
# Processing 6/7 Target550
# 6/7 Target550 FINISHED with n_TFs: 41
# Processing 0/9 Target424
# 0/9 Target424 FINISHED with n_TFs: 49
# Processing 1/9 Target425
# 1/9 Target425 FINISHED with n_TFs: 49
# Processing 2/9 Target426
# 2/9 Target426 FINISHED with n_TFs: 49
# Processing 3/9 Target430
# 3/9 Target430 FINISHED with n_TFs: 49
# Processing 4/9 Target436
# 4/9 Target436 FINISHED with n_TFs: 49
# Processing 5/9 Target440
# 5/9 Target440 FINISHED with n_TFs: 49
# Processing 6/9 Target447
# 6/9 Target447 FINISHED with n_TFs: 49
# Processing 7/9 Target452
# 7/9 Target452 FINISHED with n_TFs: 49
# Processing 8/9 Target455
# 8/9 Target455 FINISHED with n_TFs: 49
# Processing 0/5 Target281
# 0/5 Target281 FINISHED with n_TFs: 29
# Processing 1/5 Target284
# 1/5 Target284 FINISHED with n_TFs: 29
# Processing 2/5 Target285
# 2/5 Target285 FINISHED with n_TFs: 29
# Processing 3/5 Target286
# 3/5 Target286 FINISHED with n_TFs: 29
# Processing 4/5 Target287
# 4/5 Target287 FINISHED with n_TFs: 29
# Processing 0/8 Target172
# 0/8 Target172 FINISHED with n_TFs: 37
# Processing 1/8 Target173
# 1/8 Target173 FINISHED with n_TFs: 37
# Processing 2/8 Target174
# 2/8 Target174 FINISHED with n_TFs: 37
# Processing 3/8 Target175
# 3/8 Target175 FINISHED with n_TFs: 37
# Processing 4/8 Target176
# 4/8 Target176 FINISHED with n_TFs: 37
# Processing 5/8 Target178
# 5/8 Target178 FINISHED with n_TFs: 37
# Processing 6/8 Target180
# 6/8 Target180 FINISHED with n_TFs: 37
# Processing 7/8 Target182
# 7/8 Target182 FINISHED with n_TFs: 37
# Processing 0/3 Target265
# 0/3 Target265 FINISHED with n_TFs: 19
# Processing 1/3 Target266
# 1/3 Target266 FINISHED with n_TFs: 19
# Processing 2/3 Target267
# 2/3 Target267 FINISHED with n_TFs: 19
# Processing 0/8 Target28
# 0/8 Target28 FINISHED with n_TFs: 37
# Processing 1/8 Target29
# 1/8 Target29 FINISHED with n_TFs: 37
# Processing 2/8 Target30
# 2/8 Target30 FINISHED with n_TFs: 37
# Processing 3/8 Target31
# 3/8 Target31 FINISHED with n_TFs: 37
# Processing 4/8 Target36
# 4/8 Target36 FINISHED with n_TFs: 37
# Processing 5/8 Target42
# 5/8 Target42 FINISHED with n_TFs: 37
# Processing 6/8 Target43
# 6/8 Target43 FINISHED with n_TFs: 37
# Processing 7/8 Target47
# 7/8 Target47 FINISHED with n_TFs: 37
# Processing 0/4 Target641
# 0/4 Target641 FINISHED with n_TFs: 29
# Processing 1/4 Target642
# 1/4 Target642 FINISHED with n_TFs: 29
# Processing 2/4 Target643
# 2/4 Target643 FINISHED with n_TFs: 29
# Processing 3/4 Target645
# 3/4 Target645 FINISHED with n_TFs: 29
# Processing 0/8 Target96
# 0/8 Target96 FINISHED with n_TFs: 37
# Processing 1/8 Target97
# 1/8 Target97 FINISHED with n_TFs: 37
# WARNING: 2/8 Target98 not recoverable due to insufficient samples.
# WARNING: 3/8 Target99 not recoverable due to insufficient samples.
# Processing 4/8 Target100
# 4/8 Target100 FINISHED with n_TFs: 37
# WARNING: 5/8 Target101 not recoverable due to insufficient samples.
# Processing 6/8 Target102
# 6/8 Target102 FINISHED with n_TFs: 37
# Processing 7/8 Target103
# 7/8 Target103 FINISHED with n_TFs: 37
# Processing 0/4 B3_TF1
# 0/4 B3_TF1 FINISHED with n_TFs: 18
# Processing 1/4 B3_TF2
# 1/4 B3_TF2 FINISHED with n_TFs: 18
# Processing 2/4 B4_TF1
# 2/4 B4_TF1 FINISHED with n_TFs: 18
# Processing 3/4 B5_TF1
# 3/4 B5_TF1 FINISHED with n_TFs: 18
# Processing 0/8 Target7
# 0/8 Target7 FINISHED with n_TFs: 37
# Processing 1/8 Target9
# 1/8 Target9 FINISHED with n_TFs: 37
# Processing 2/8 Target10
# 2/8 Target10 FINISHED with n_TFs: 37
# Processing 3/8 Target11
# 3/8 Target11 FINISHED with n_TFs: 37
# Processing 4/8 Target12
# 4/8 Target12 FINISHED with n_TFs: 37
# Processing 5/8 Target14
# 5/8 Target14 FINISHED with n_TFs: 37
# Processing 6/8 Target16
# 6/8 Target16 FINISHED with n_TFs: 37
# Processing 7/8 Target18
# 7/8 Target18 FINISHED with n_TFs: 37
# Processing 0/9 Target702
# 0/9 Target702 FINISHED with n_TFs: 49
# Processing 1/9 Target703
# 1/9 Target703 FINISHED with n_TFs: 49
# Processing 2/9 Target704
# 2/9 Target704 FINISHED with n_TFs: 49
# Processing 3/9 Target705
# 3/9 Target705 FINISHED with n_TFs: 49
# Processing 4/9 Target706
# 4/9 Target706 FINISHED with n_TFs: 49
# Processing 5/9 Target707
# 5/9 Target707 FINISHED with n_TFs: 49
# Processing 6/9 Target710
# 6/9 Target710 FINISHED with n_TFs: 49
# Processing 7/9 Target711
# 7/9 Target711 FINISHED with n_TFs: 49
# Processing 8/9 Target712
# 8/9 Target712 FINISHED with n_TFs: 49
# Processing 0/5 Target398
# 0/5 Target398 FINISHED with n_TFs: 29
# Processing 1/5 Target399
# 1/5 Target399 FINISHED with n_TFs: 29
# Processing 2/5 Target400
# 2/5 Target400 FINISHED with n_TFs: 29
# Processing 3/5 Target401
# 3/5 Target401 FINISHED with n_TFs: 29
# Processing 4/5 Target402
# 4/5 Target402 FINISHED with n_TFs: 29
# Processing 0/8 Target314
# 0/8 Target314 FINISHED with n_TFs: 37
# WARNING: 1/8 Target320 not recoverable due to insufficient samples.
# Processing 2/8 Target326
# 2/8 Target326 FINISHED with n_TFs: 37
# Processing 3/8 Target328
# 3/8 Target328 FINISHED with n_TFs: 37
# Processing 4/8 Target331
# 4/8 Target331 FINISHED with n_TFs: 37
# WARNING: 5/8 Target333 not recoverable due to insufficient samples.
# Processing 6/8 Target347
# 6/8 Target347 FINISHED with n_TFs: 37
# Processing 7/8 Target348
# 7/8 Target348 FINISHED with n_TFs: 37
# Processing 0/4 Target16
# 0/4 Target16 FINISHED with n_TFs: 19
# Processing 1/4 Target17
# 1/4 Target17 FINISHED with n_TFs: 19
# Processing 2/4 Target19
# 2/4 Target19 FINISHED with n_TFs: 19
# Processing 3/4 Target20
# 3/4 Target20 FINISHED with n_TFs: 19
# Processing 0/8 Target49
# 0/8 Target49 FINISHED with n_TFs: 37
# Processing 1/8 Target50
# 1/8 Target50 FINISHED with n_TFs: 37
# Processing 2/8 Target51
# 2/8 Target51 FINISHED with n_TFs: 37
# Processing 3/8 Target52
# 3/8 Target52 FINISHED with n_TFs: 37
# Processing 4/8 Target53
# 4/8 Target53 FINISHED with n_TFs: 37
# Processing 5/8 Target57
# 5/8 Target57 FINISHED with n_TFs: 37
# Processing 6/8 Target59
# 6/8 Target59 FINISHED with n_TFs: 37
# Processing 7/8 Target60
# 7/8 Target60 FINISHED with n_TFs: 37
# Processing 0/4 Target659
# 0/4 Target659 FINISHED with n_TFs: 29
# Processing 1/4 Target660
# 1/4 Target660 FINISHED with n_TFs: 29
# Processing 2/4 Target661
# 2/4 Target661 FINISHED with n_TFs: 29
# Processing 3/4 Target662
# 3/4 Target662 FINISHED with n_TFs: 29
# Processing 0/7 Target435
# 0/7 Target435 FINISHED with n_TFs: 37
# Processing 1/7 Target436
# 1/7 Target436 FINISHED with n_TFs: 37
# Processing 2/7 Target437
# 2/7 Target437 FINISHED with n_TFs: 37
# WARNING: 3/7 Target438 not recoverable due to insufficient samples.
# Processing 4/7 Target439
# 4/7 Target439 FINISHED with n_TFs: 37
# Processing 5/7 Target440
# 5/7 Target440 FINISHED with n_TFs: 37
# Processing 6/7 Target441
# 6/7 Target441 FINISHED with n_TFs: 37
# Processing 0/4 Target101
# 0/4 Target101 FINISHED with n_TFs: 19
# Processing 1/4 Target102
# 1/4 Target102 FINISHED with n_TFs: 19
# Processing 2/4 Target103
# 2/4 Target103 FINISHED with n_TFs: 19
# Processing 3/4 Target110
# 3/4 Target110 FINISHED with n_TFs: 19
# Processing 0/8 B1_TF1
# 0/8 B1_TF1 FINISHED with n_TFs: 36
# Processing 1/8 B1_TF2
# 1/8 B1_TF2 FINISHED with n_TFs: 36
# Processing 2/8 B2_TF1
# 2/8 B2_TF1 FINISHED with n_TFs: 36
# Processing 3/8 B3_TF1
# 3/8 B3_TF1 FINISHED with n_TFs: 36
# Processing 4/8 B4_TF1
# 4/8 B4_TF1 FINISHED with n_TFs: 36
# Processing 5/8 C1_TF1
# 5/8 C1_TF1 FINISHED with n_TFs: 36
# Processing 6/8 C1_TF2
# 6/8 C1_TF2 FINISHED with n_TFs: 36
# Processing 7/8 C2_TF1
# 7/8 C2_TF1 FINISHED with n_TFs: 36
# Processing 0/7 Target783
# 0/7 Target783 FINISHED with n_TFs: 37
# Processing 1/7 Target784
# 1/7 Target784 FINISHED with n_TFs: 37
# Processing 2/7 Target785
# 2/7 Target785 FINISHED with n_TFs: 37
# Processing 3/7 Target786
# 3/7 Target786 FINISHED with n_TFs: 37
# Processing 4/7 Target795
# 4/7 Target795 FINISHED with n_TFs: 37
# WARNING: 5/7 Target796 not recoverable due to insufficient samples.
# WARNING: 6/7 Target800 not recoverable due to insufficient samples.
# Processing 0/4 C2_TF2
# 0/4 C2_TF2 FINISHED with n_TFs: 18
# Processing 1/4 C3_TF1
# 1/4 C3_TF1 FINISHED with n_TFs: 18
# Processing 2/4 C3_TF2
# 2/4 C3_TF2 FINISHED with n_TFs: 18
# Processing 3/4 C3_TF3
# 3/4 C3_TF3 FINISHED with n_TFs: 18
# Processing 0/8 C3_TF1
# 0/8 C3_TF1 FINISHED with n_TFs: 36
# Processing 1/8 C4_TF1
# 1/8 C4_TF1 FINISHED with n_TFs: 36
# Processing 2/8 C5_TF1
# 2/8 C5_TF1 FINISHED with n_TFs: 36
# Processing 3/8 C6_TF1
# 3/8 C6_TF1 FINISHED with n_TFs: 36
# Processing 4/8 C6_TF2
# 4/8 C6_TF2 FINISHED with n_TFs: 36
# Processing 5/8 C6_TF3
# 5/8 C6_TF3 FINISHED with n_TFs: 36
# Processing 6/8 C7_TF1
# 6/8 C7_TF1 FINISHED with n_TFs: 36
# Processing 7/8 C8_TF1
# 7/8 C8_TF1 FINISHED with n_TFs: 36
# Processing 0/4 Target789
# 0/4 Target789 FINISHED with n_TFs: 29
# Processing 1/4 Target790
# 1/4 Target790 FINISHED with n_TFs: 29
# Processing 2/4 Target794
# 2/4 Target794 FINISHED with n_TFs: 29
# Processing 3/4 Target800
# 3/4 Target800 FINISHED with n_TFs: 29
# Processing 0/8 Target247
# 0/8 Target247 FINISHED with n_TFs: 37
# Processing 1/8 Target248
# 1/8 Target248 FINISHED with n_TFs: 37
# Processing 2/8 Target250
# 2/8 Target250 FINISHED with n_TFs: 37
# Processing 3/8 Target251
# 3/8 Target251 FINISHED with n_TFs: 37
# Processing 4/8 Target252
# 4/8 Target252 FINISHED with n_TFs: 37
# Processing 5/8 Target253
# 5/8 Target253 FINISHED with n_TFs: 37
# Processing 6/8 Target255
# 6/8 Target255 FINISHED with n_TFs: 37
# Processing 7/8 Target256
# 7/8 Target256 FINISHED with n_TFs: 37
# Processing 0/3 Target275
# 0/3 Target275 FINISHED with n_TFs: 19
# Processing 1/3 Target276
# 1/3 Target276 FINISHED with n_TFs: 19
# Processing 2/3 Target277
# 2/3 Target277 FINISHED with n_TFs: 19
# Processing 0/8 Target101
# 0/8 Target101 FINISHED with n_TFs: 37
# Processing 1/8 Target102
# 1/8 Target102 FINISHED with n_TFs: 37
# Processing 2/8 Target103
# 2/8 Target103 FINISHED with n_TFs: 37
# Processing 3/8 Target104
# 3/8 Target104 FINISHED with n_TFs: 37
# Processing 4/8 Target105
# 4/8 Target105 FINISHED with n_TFs: 37
# Processing 5/8 Target106
# 5/8 Target106 FINISHED with n_TFs: 37
# Processing 6/8 Target107
# 6/8 Target107 FINISHED with n_TFs: 37
# Processing 7/8 Target108
# 7/8 Target108 FINISHED with n_TFs: 37
# Processing 0/4 Target707
# 0/4 Target707 FINISHED with n_TFs: 29
# Processing 1/4 Target708
# 1/4 Target708 FINISHED with n_TFs: 29
# Processing 2/4 Target709
# 2/4 Target709 FINISHED with n_TFs: 29
# Processing 3/4 Target710
# 3/4 Target710 FINISHED with n_TFs: 29
# Processing 0/7 Target552
# 0/7 Target552 FINISHED with n_TFs: 37
# Processing 1/7 Target553
# 1/7 Target553 FINISHED with n_TFs: 37
# Processing 2/7 Target554
# 2/7 Target554 FINISHED with n_TFs: 37
# Processing 3/7 Target555
# 3/7 Target555 FINISHED with n_TFs: 37
# Processing 4/7 Target556
# 4/7 Target556 FINISHED with n_TFs: 37
# Processing 5/7 Target557
# 5/7 Target557 FINISHED with n_TFs: 37
# Processing 6/7 Target558
# 6/7 Target558 FINISHED with n_TFs: 37
# Processing 0/3 Target252
# 0/3 Target252 FINISHED with n_TFs: 19
# Processing 1/3 Target253
# 1/3 Target253 FINISHED with n_TFs: 19
# Processing 2/3 Target254
# 2/3 Target254 FINISHED with n_TFs: 19
# Processing 0/8 Target92
# 0/8 Target92 FINISHED with n_TFs: 37
# Processing 1/8 Target93
# 1/8 Target93 FINISHED with n_TFs: 37
# Processing 2/8 Target95
# 2/8 Target95 FINISHED with n_TFs: 37
# Processing 3/8 Target96
# 3/8 Target96 FINISHED with n_TFs: 37
# Processing 4/8 Target97
# 4/8 Target97 FINISHED with n_TFs: 37
# Processing 5/8 Target98
# 5/8 Target98 FINISHED with n_TFs: 37
# Processing 6/8 Target99
# 6/8 Target99 FINISHED with n_TFs: 37
# Processing 7/8 Target100
# 7/8 Target100 FINISHED with n_TFs: 37
#     finished (0:17:14) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)

# %%
pd.DataFrame({"velocity": velocity_correlation, "grn": grn_correlation})
# Out:
#     velocity       grn
# 0   0.046940  0.451943
# 1   0.027392  0.581518
# 2   0.011939  0.690335
# 3  -0.001472  0.650858
# 4   0.012958  0.651840
# 5  -0.002415  0.523596
# 6  -0.004171  0.652698
# 7   0.037092  0.504753
# 8  -0.010419  0.657961
# 9   0.024667  0.547364
# 10 -0.020761  0.487150
# 11  0.000998  0.446180
# 12  0.011447  0.668401
# 13 -0.020111  0.694352
# 14  0.011284  0.628837
# 15  0.000470  0.605307
# 16 -0.012091  0.540858
# 17 -0.002043  0.468821
# 18 -0.007214  0.689165
# 19  0.037481  0.482150
# 20  0.017244  0.492023
# 21  0.043269  0.477645
# 22  0.014624  0.743747
# 23 -0.030481  0.525972
# 24 -0.031362  0.683455
# 25  0.003220  0.558198
# 26  0.031860  0.484434
# 27 -0.039174  0.610313
# 28  0.020691  0.607102
# 29  0.009500  0.464357

# %%
if SAVE_DATA:
    pd.DataFrame({"velocity": velocity_correlation, "grn": grn_correlation}).to_parquet(
        path=DATA_DIR / DATASET / COMPLEXITY / "results" / "tfvelo_correlation.parquet"
    )

# %%
if SAVE_DATA:
    df = pd.DataFrame(velocity_correlation_all).T
    df.columns = df.columns.astype(str)
    df.to_parquet(path=DATA_DIR / DATASET / COMPLEXITY / "results" / "tfvelo_correlation_all.parquet")
